# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"\\scripts")

# %%
import numpy as np
import torch
from torch.quasirandom import SobolEngine
tkwargs = {"dtype": torch.double,
           "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
#            "device": torch.device("cpu")
          }
from botorch.models.transforms.outcome import Standardize
import matplotlib.pyplot as plt
from MAB_BO_utils import *
# Out:
# [pyKeOps]: Warning, no cuda detected. Switching to cpu only.

# %%
# global parameters


d = 1
m = 2*(d+1)
C = 3
BOUNDS = torch.tensor([[-1.0]*(d), [3.0]*(d)])


N_CANDIDATES = 1
SAMPLER = 'cholesky'
N_SAMPLES = 1000
NU = 0.5

N_TRIALS = 3
N_ITERS = 40

# %%
# THOMPSON SAMPLING VISUALIZATION

# define train_X and train_y
train_X = generate_X(m, d, C, BOUNDS, seed=0)
train_y = modified_neg_ackley(train_X)

# normalize X
train_X_normalized = normalize_with_bounds(train_X, BOUNDS)

# initialize model
models = initialize_models(train_X_normalized, train_y, nu=NU, sampler=SAMPLER)



fig, ax = plt.subplots(1, C, figsize=(15, 4), sharey=True)
x = np.linspace(-1, 3, 100)
X = torch.tensor(x).unsqueeze(-1)

for c in range(C):
    
    # PLOT FUNCTION
    categories = torch.tensor([c]*X.shape[0]).unsqueeze(-1)
    X_ = torch.cat([categories, X], dim=-1)
    y = modified_neg_ackley(X_).squeeze(0).detach().numpy()
    ax[c].plot(x, y)
    ax[c].set_title(f'c={c}')
    
    # PLOT DATAPOINTS
    mask = train_X[..., 0] == c
    X_ = train_X[mask, 1:].squeeze(0).detach().numpy()
    y_ = train_y[mask].squeeze(0).detach().numpy()
    ax[c].scatter(X_, y_, s=10, c='r')
    
    # PLOT THOMPSON SAMPLES
    model = models[c]
    _, _, X_, y_ = thompson_sampling(model, d, N_SAMPLES, sampler=SAMPLER)
    categories = torch.tensor([c]*X_.shape[0]).unsqueeze(-1)
    X_ = torch.cat([categories, X_], dim=-1)
    X_ = denormalize_with_bounds(X_, BOUNDS)
    X_ = X_[:, 1:].squeeze(-1).detach().numpy()
    y_ = y_.squeeze(-1).detach().numpy()
    
    ax[c].scatter(X_, y_, c='c', alpha=0.1, s=0.5)
    
    
# picked category
cat = pick_category(models, d, N_SAMPLES, sampler=SAMPLER)
print(f"picked category: {cat}")
# Out:
# picked category: 0

# %%
# BO LOOP

best_values = torch.empty(N_TRIALS, N_ITERS, **tkwargs)

for t in range(N_TRIALS):
    
    # generate starting dataset
    train_X = generate_X(m, d, C, BOUNDS, seed=t)
    train_y = modified_neg_ackley(train_X)

    
    for i in range(N_ITERS):
        
        print(f"trial {t+1}/{N_TRIALS} | iteration {i+1}/{N_ITERS} | ", end='')
    
        # normalize X 
        train_X_normalized = normalize_with_bounds(train_X, BOUNDS)
        # standardize y
        standardizer = Standardize(1)
        train_y_standardized = standardizer(train_y)[0]

        # initialize model
        models = initialize_models(train_X_normalized, train_y, nu=NU, sampler=SAMPLER)
        
        # get candidates
        new_X = get_candidates(models, d, N_CANDIDATES, N_SAMPLES, sampler=SAMPLER)
        
        # denormalize candidates
        new_X = denormalize_with_bounds(new_X, BOUNDS)
        
        # evaluate objective
        new_y = modified_neg_ackley(new_X)
        
        # update train_X and train_y
        train_X = torch.cat([train_X, new_X], dim=0)
        train_y = torch.cat([train_y, new_y], dim=0)
        
        # update best values
        best = train_y.max().item()
        print(f"best = {best}")
        best_values[t, i] = best
# Out:
# trial 1/3 | iteration 1/40 | picked category: 0 | sampled posterior value = -2.773133229536012
# best = -3.5847250328427944
# trial 1/3 | iteration 2/40 | picked category: 0 | sampled posterior value = -2.9898639520556465
# best = -0.8357474630301209
# trial 1/3 | iteration 3/40 | picked category: 0 | sampled posterior value = 0.372121082444564
# best = -0.09451946281652512
# trial 1/3 | iteration 4/40 | picked category: 0 | sampled posterior value = -0.3452340212715389
# best = -0.09451946281652512
# trial 1/3 | iteration 5/40 | picked category: 0 | sampled posterior value = -0.41613378313055505
# best = -0.09451946281652512
# trial 1/3 | iteration 6/40 | picked category: 0 | sampled posterior value = 0.2970850736111261
# best = -0.020986026910730704
# trial 1/3 | iteration 7/40 | picked category: 0 | sampled posterior value = -0.30735928024256076
# best = -0.020986026910730704
# trial 1/3 | iteration 8/40 | picked category: 0 | sampled posterior value = -0.34064015699131966
# best = -0.020986026910730704
# trial 1/3 | iteration 9/40 | picked category: 0 | sampled posterior value = -0.05051423599911592
# best = -0.020986026910730704
# trial 1/3 | iteration 10/40 | picked category: 0 | sampled posterior value = -0.03975358289695041
# best = -0.020986026910730704
# trial 1/3 | iteration 11/40 | picked category: 0 | sampled posterior value = -0.2670696092889283
# best = -0.020986026910730704
# trial 1/3 | iteration 12/40 | picked category: 0 | sampled posterior value = 0.1420716084827418
# best = -0.020986026910730704
# trial 1/3 | iteration 13/40 | picked category: 0 | sampled posterior value = 0.007985189162149929
# best = -0.020986026910730704
# trial 1/3 | iteration 14/40 | picked category: 0 | sampled posterior value = 0.018809457179004584
# best = -0.010322391765694494
# trial 1/3 | iteration 15/40 | picked category: 0 | sampled posterior value = 0.06965077652598695
# best = -0.010322391765694494
# trial 1/3 | iteration 16/40 | picked category: 0 | sampled posterior value = 0.0459803943351515
# best = -0.010322391765694494
# trial 1/3 | iteration 17/40 | picked category: 0 | sampled posterior value = 0.08278509816123653
# best = -0.010322391765694494
# trial 1/3 | iteration 18/40 | picked category: 0 | sampled posterior value = 0.16444890885800173
# best = -0.010322391765694494
# trial 1/3 | iteration 19/40 | picked category: 0 | sampled posterior value = 0.07252899883822386
# best = -0.009455498798115247
# trial 1/3 | iteration 20/40 | picked category: 0 | sampled posterior value = 0.028263875859908416
# best = -0.009455498798115247
# trial 1/3 | iteration 21/40 | picked category: 0 | sampled posterior value = 0.06933711316473357
# best = -0.009455498798115247
# trial 1/3 | iteration 22/40 | picked category: 0 | sampled posterior value = 0.046665280234244544
# best = -0.009455498798115247
# trial 1/3 | iteration 23/40 | picked category: 0 | sampled posterior value = 0.05041288285713291
# best = -0.009455498798115247
# trial 1/3 | iteration 24/40 | picked category: 0 | sampled posterior value = 0.07492338702675094
# best = -0.009455498798115247
# trial 1/3 | iteration 25/40 | picked category: 0 | sampled posterior value = 0.11818560490048957
# best = -0.0017780354776957275
# trial 1/3 | iteration 26/40 | picked category: 0 | sampled posterior value = 0.06476557915416786
# best = -0.0017780354776957275
# trial 1/3 | iteration 27/40 | picked category: 0 | sampled posterior value = 0.00013036701368126374
# best = -0.0017780354776957275
# trial 1/3 | iteration 28/40 | picked category: 0 | sampled posterior value = 0.05890161927292559
# best = -0.0017780354776957275
# trial 1/3 | iteration 29/40 | picked category: 0 | sampled posterior value = 0.06831975081936423
# best = -0.0017780354776957275
# trial 1/3 | iteration 30/40 | picked category: 0 | sampled posterior value = 0.011414946717267935
# best = -0.0017780354776957275
# trial 1/3 | iteration 31/40 | picked category: 0 | sampled posterior value = 0.02914964625426887
# best = -0.0017780354776957275
# trial 1/3 | iteration 32/40 | picked category: 0 | sampled posterior value = 0.03475081413588469
# best = -0.0017780354776957275
# trial 1/3 | iteration 33/40 | picked category: 0 | sampled posterior value = 0.00996255610139095
# best = -0.0017780354776957275
# trial 1/3 | iteration 34/40 | picked category: 0 | sampled posterior value = 0.10371992450843831
# best = -0.0017780354776957275
# trial 1/3 | iteration 35/40 | picked category: 0 | sampled posterior value = 0.015587714797872652
# best = -0.0017780354776957275
# trial 1/3 | iteration 36/40 | picked category: 0 | sampled posterior value = -0.012464414570842585
# best = -0.0017780354776957275
# trial 1/3 | iteration 37/40 | picked category: 0 | sampled posterior value = 0.7020246171688127
# best = -0.0017780354776957275
# trial 1/3 | iteration 38/40 | picked category: 0 | sampled posterior value = 0.010787430289737047
# best = -0.0017780354776957275
# trial 1/3 | iteration 39/40 | picked category: 0 | sampled posterior value = 0.07146889079704383
# best = -0.0017780354776957275
# trial 1/3 | iteration 40/40 | picked category: 0 | sampled posterior value = 0.012070730756504739
# best = -0.0017780354776957275
# trial 2/3 | iteration 1/40 | picked category: 0 | sampled posterior value = -3.044227136301259
# best = -1.9973197645685272
# trial 2/3 | iteration 2/40 | picked category: 0 | sampled posterior value = -2.0955527989846225
# best = -1.9973197645685272
# trial 2/3 | iteration 3/40 | picked category: 0 | sampled posterior value = -3.0257196303239797
# best = -1.9973197645685272
# trial 2/3 | iteration 4/40 | picked category: 0 | sampled posterior value = -2.4522881347798697
# best = -1.9973197645685272
# trial 2/3 | iteration 5/40 | picked category: 0 | sampled posterior value = -2.312900439399264
# best = -1.9973197645685272
# trial 2/3 | iteration 6/40 | picked category: 0 | sampled posterior value = -2.5007877424164096
# best = -1.9973197645685272
# trial 2/3 | iteration 7/40 | picked category: 0 | sampled posterior value = -2.6118638492576354
# best = -1.337553746892493
# trial 2/3 | iteration 8/40 | picked category: 0 | sampled posterior value = -1.960759498169844
# best = -1.337553746892493
# trial 2/3 | iteration 9/40 | picked category: 0 | sampled posterior value = -1.5424859391373018
# best = -0.9607087076173113
# trial 2/3 | iteration 10/40 | picked category: 0 | sampled posterior value = -2.073043542172955
# best = -0.9607087076173113
# trial 2/3 | iteration 11/40 | picked category: 0 | sampled posterior value = -2.040685585962256
# best = -0.9607087076173113
# trial 2/3 | iteration 12/40 | picked category: 0 | sampled posterior value = -1.8223073186274739
# best = -0.5331344655987462
# trial 2/3 | iteration 13/40 | picked category: 0 | sampled posterior value = -1.79528568142911
# best = -0.43294705848115145
# trial 2/3 | iteration 14/40 | picked category: 0 | sampled posterior value = -1.611658702603215
# best = -0.43294705848115145
# trial 2/3 | iteration 15/40 | picked category: 0 | sampled posterior value = -0.9030470813836213
# best = -0.364319471794492
# trial 2/3 | iteration 16/40 | picked category: 0 | sampled posterior value = -1.435523530055311
# best = -0.364319471794492
# trial 2/3 | iteration 17/40 | picked category: 0 | sampled posterior value = -0.7764132302354733
# best = -0.364319471794492
# trial 2/3 | iteration 18/40 | picked category: 0 | sampled posterior value = -0.4110954726278776
# best = -0.364319471794492
# trial 2/3 | iteration 19/40 | picked category: 0 | sampled posterior value = -0.374766971503194
# best = -0.364319471794492
# trial 2/3 | iteration 20/40 | picked category: 0 | sampled posterior value = -0.3442572571023714
# best = -0.3463963692200491
# trial 2/3 | iteration 21/40 | picked category: 0 | sampled posterior value = -0.34200337130089964
# best = -0.3463963692200491
# trial 2/3 | iteration 22/40 | picked category: 0 | sampled posterior value = -0.3453514121650795
# best = -0.3463963692200491
# trial 2/3 | iteration 23/40 | picked category: 0 | sampled posterior value = -0.259902073485246
# best = -0.18338203680746945
# trial 2/3 | iteration 24/40 | picked category: 0 | sampled posterior value = -0.17435205705749388
# best = -0.18338203680746945
# trial 2/3 | iteration 25/40 | picked category: 0 | sampled posterior value = -0.2291680813047025
# best = -0.12673746417946719
# trial 2/3 | iteration 26/40 | picked category: 0 | sampled posterior value = -0.1469460204116757
# best = -0.1239508749476852
# trial 2/3 | iteration 27/40 | picked category: 0 | sampled posterior value = -0.1471859920317238
# best = -0.1239508749476852
# trial 2/3 | iteration 28/40 | picked category: 0 | sampled posterior value = -0.10314306578756083
# best = -0.054300806037229865
# trial 2/3 | iteration 29/40 | picked category: 0 | sampled posterior value = -0.07079529638216242
# best = -0.054300806037229865
# trial 2/3 | iteration 30/40 | picked category: 0 | sampled posterior value = -0.0436792185202631
# best = -0.054300806037229865
# trial 2/3 | iteration 31/40 | picked category: 0 | sampled posterior value = -0.05522558160438619
# best = -0.054300806037229865
# trial 2/3 | iteration 32/40 | picked category: 0 | sampled posterior value = -0.017811814165781814
# best = -0.054300806037229865
# trial 2/3 | iteration 33/40 | picked category: 0 | sampled posterior value = -0.05196994706799728
# best = -0.05429173795943898
# trial 2/3 | iteration 34/40 | picked category: 0 | sampled posterior value = -0.04571178854028971
# best = -0.05429173795943898
# trial 2/3 | iteration 35/40 | picked category: 0 | sampled posterior value = -0.018385799948917814
# best = -0.05429173795943898
# trial 2/3 | iteration 36/40 | picked category: 0 | sampled posterior value = -0.054516107762329395
# best = -0.05429173795943898
# trial 2/3 | iteration 37/40 | picked category: 0 | sampled posterior value = -0.005257808639248324
# best = -0.02066459315279845
# trial 2/3 | iteration 38/40 | picked category: 0 | sampled posterior value = 0.040705930275963004
# best = -0.011383948407541755
# trial 2/3 | iteration 39/40 | picked category: 0 | sampled posterior value = 0.04282657441890231
# best = -0.011383948407541755
# trial 2/3 | iteration 40/40 | picked category: 0 | sampled posterior value = 0.03630323798662302
# best = -0.00754628118696532
# trial 3/3 | iteration 1/40 | picked category: 1 | sampled posterior value = -1.6633530293463545
# best = -0.5142793863840436
# trial 3/3 | iteration 2/40 | picked category: 1 | sampled posterior value = -0.16193220331955915
# best = -0.5142793863840436
# trial 3/3 | iteration 3/40 | picked category: 1 | sampled posterior value = -0.5090757223098025
# best = -0.5142793863840436
# trial 3/3 | iteration 4/40 | picked category: 1 | sampled posterior value = -0.6683001546444505
# best = -0.5090040443870447
# trial 3/3 | iteration 5/40 | picked category: 1 | sampled posterior value = 0.12842804478380265
# best = -0.5090040443870447
# trial 3/3 | iteration 6/40 | picked category: 1 | sampled posterior value = 0.13560858915613228
# best = -0.5090040443870447
# trial 3/3 | iteration 7/40 | picked category: 1 | sampled posterior value = -0.13380965197142092
# best = -0.5090040443870447
# trial 3/3 | iteration 8/40 | picked category: 1 | sampled posterior value = -0.5894102576797341
# best = -0.5072724522414309
# trial 3/3 | iteration 9/40 | picked category: 1 | sampled posterior value = -0.38147698268523167
# best = -0.5072724522414309
# trial 3/3 | iteration 10/40 | picked category: 1 | sampled posterior value = -0.3680634017985961
# best = -0.5072724522414309
# trial 3/3 | iteration 11/40 | picked category: 1 | sampled posterior value = -0.41213968710137
# best = -0.5072724522414309
# trial 3/3 | iteration 12/40 | picked category: 1 | sampled posterior value = -0.3820742273869738
# best = -0.5005945361566124
# trial 3/3 | iteration 13/40 | picked category: 1 | sampled posterior value = -0.4061044564023694
# best = -0.5005945361566124
# trial 3/3 | iteration 14/40 | picked category: 1 | sampled posterior value = -0.5158474743099251
# best = -0.5005945361566124
# trial 3/3 | iteration 15/40 | picked category: 1 | sampled posterior value = -0.4247087216558263
# best = -0.5005945361566124
# trial 3/3 | iteration 16/40 | picked category: 1 | sampled posterior value = -0.49492852481865285
# best = -0.5005945361566124
# trial 3/3 | iteration 17/40 | picked category: 0 | sampled posterior value = -1.6743376722079786
# best = -0.5005945361566124
# trial 3/3 | iteration 18/40 | picked category: 1 | sampled posterior value = -0.39972754506822755
# best = -0.5005945361566124
# trial 3/3 | iteration 19/40 | picked category: 1 | sampled posterior value = -0.4354489488920176
# best = -0.5005945361566124
# trial 3/3 | iteration 20/40 | picked category: 1 | sampled posterior value = -0.48602140079753464
# best = -0.5005945361566124
# trial 3/3 | iteration 21/40 | picked category: 1 | sampled posterior value = -0.45007231771645095
# best = -0.5005945361566124
# trial 3/3 | iteration 22/40 | picked category: 1 | sampled posterior value = -0.5021788793562547
# best = -0.5005945361566124
# trial 3/3 | iteration 23/40 | picked category: 1 | sampled posterior value = -0.4531864732269584
# best = -0.5005945361566124
# trial 3/3 | iteration 24/40 | picked category: 1 | sampled posterior value = -0.4528310969189595
# best = -0.5005945361566124
# trial 3/3 | iteration 25/40 | picked category: 1 | sampled posterior value = -0.4857423538996393
# best = -0.5005945361566124
# trial 3/3 | iteration 26/40 | picked category: 1 | sampled posterior value = -0.48433360771097256
# best = -0.5005945361566124
# trial 3/3 | iteration 27/40 | picked category: 1 | sampled posterior value = -0.5251705120230192
# best = -0.5005945361566124
# trial 3/3 | iteration 28/40 | picked category: 1 | sampled posterior value = -0.5134942660254385
# best = -0.5005945361566124
# trial 3/3 | iteration 29/40 | picked category: 0 | sampled posterior value = -2.852767026548996
# best = -0.5005945361566124
# trial 3/3 | iteration 30/40 | picked category: 1 | sampled posterior value = -0.5232634306881466
# best = -0.5005945361566124
# trial 3/3 | iteration 31/40 | picked category: 1 | sampled posterior value = -0.48862167764829106
# best = -0.5005945361566124
# trial 3/3 | iteration 32/40 | picked category: 1 | sampled posterior value = -0.5202346263844579
# best = -0.5005945361566124
# trial 3/3 | iteration 33/40 | picked category: 1 | sampled posterior value = -0.4403132166670751
# best = -0.5005945361566124
# trial 3/3 | iteration 34/40 | picked category: 1 | sampled posterior value = -0.4042714658370753
# best = -0.5005945361566124
# trial 3/3 | iteration 35/40 | picked category: 1 | sampled posterior value = -0.470866418210886
# best = -0.5002887933566567
# trial 3/3 | iteration 36/40 | picked category: 1 | sampled posterior value = -0.3277359059034692
# best = -0.5002887933566567
# trial 3/3 | iteration 37/40 | picked category: 1 | sampled posterior value = -0.4872663507878263
# best = -0.5002887933566567
# trial 3/3 | iteration 38/40 | picked category: 1 | sampled posterior value = -0.5155471086132233
# best = -0.5002887933566567
# trial 3/3 | iteration 39/40 | picked category: 1 | sampled posterior value = -0.49337234724168655
# best = -0.5002887933566567
# trial 3/3 | iteration 40/40 | picked category: 1 | sampled posterior value = -0.5031143265121499
# best = -0.5002887933566567
