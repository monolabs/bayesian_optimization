# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"\\scripts")

# %%
import numpy as np
import torch
tkwargs = {"dtype": torch.double,
#            "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
           "device": torch.device("cpu")
          }

from botorch.acquisition.monte_carlo import qExpectedImprovement
from botorch.sampling.samplers import SobolQMCNormalSampler
import matplotlib.pyplot as plt

import one_hot_BO_utils as oh
import MAB_BO_utils as mab

# %%
# global parameters

d = 5
m = 2*(d+1)
C = 5
BOUNDS = torch.tensor([[-1.0]*d,
                       [3.0]*d]).to(**tkwargs)
BOUNDS_ACQF = torch.tensor([[0.0]*C + [-1.0]*d,
                            [1.0]*C + [3.0]*d]).to(**tkwargs)

N_CANDIDATES = 1
N_TRIALS = 5
N_ITERS = 100
NU = 0.5

# for MAB-BO
N_THOMPSON_SAMPLES = 7000
SAMPLER = 'cholesky'

# for one-hot EI-BO
NUM_MC_SAMPLES = 256
qmc_sampler = SobolQMCNormalSampler(num_samples=NUM_MC_SAMPLES)

# %% [markdown]
# ### MAB-BO

# %%
# BO LOOP

best_values_2 = torch.empty(N_TRIALS, N_ITERS + 1, **tkwargs)

for t in range(N_TRIALS):
    
    # generate starting dataset
    train_X = mab.generate_X(m, C, BOUNDS, seed=t).to(**tkwargs)
    train_y = mab.modified_neg_ackley(train_X).to(**tkwargs)
    best_values_2[t, 0] = train_y.max().item()

    
    for i in range(1, N_ITERS + 1):
        
        print(f"trial {t+1}/{N_TRIALS} | iteration {i}/{N_ITERS}")
    
        # normalize X 
        train_X_normalized = mab.normalize_with_bounds(train_X, BOUNDS)
#         # standardize y
#         standardizer = Standardize(1)
#         train_y_standardized = standardizer(train_y)[0]

        # initialize model
        models = mab.initialize_models(train_X_normalized, train_y, nu=NU, sampler=SAMPLER)
        
        # get candidates
        new_X = mab.get_candidates(models, d, N_CANDIDATES, N_THOMPSON_SAMPLES, sampler=SAMPLER)
        
        # denormalize candidates
        new_X = mab.denormalize_with_bounds(new_X, BOUNDS)
        
        # evaluate objective
        new_y = mab.modified_neg_ackley(new_X)
        
        # update train_X and train_y
        train_X = torch.cat([train_X, new_X], dim=0)
        train_y = torch.cat([train_y, new_y], dim=0)
        
        # update best values
        best = train_y.max().item()
        print(f"best = {best}")
        best_values_2[t, i] = best
# Out:
# trial 1/5 | iteration 1/100
# picked category: 0 | sampled posterior value = -4.972819312102889
# best = -5.6585262806589505
# trial 1/5 | iteration 2/100
# picked category: 0 | sampled posterior value = -4.749002701532669
# best = -3.885882776794628
# trial 1/5 | iteration 3/100
# picked category: 0 | sampled posterior value = -4.01374968739484
# best = -3.885882776794628
# trial 1/5 | iteration 4/100
# picked category: 0 | sampled posterior value = -4.084743238228345
# best = -3.697142988559087
# trial 1/5 | iteration 5/100
# picked category: 0 | sampled posterior value = -3.600360012834966
# best = -3.697142988559087
# trial 1/5 | iteration 6/100
# picked category: 0 | sampled posterior value = -3.7930432412261097
# best = -3.0690040918540054
# trial 1/5 | iteration 7/100
# picked category: 0 | sampled posterior value = -3.6759897354443636
# best = -3.0690040918540054
# trial 1/5 | iteration 8/100
# picked category: 0 | sampled posterior value = -3.4716147205820787
# best = -3.0690040918540054
# trial 1/5 | iteration 9/100
# picked category: 0 | sampled posterior value = -3.298325073039387
# best = -3.0690040918540054
# trial 1/5 | iteration 10/100
# picked category: 0 | sampled posterior value = -4.034673136540949
# best = -3.0690040918540054
# trial 1/5 | iteration 11/100
# picked category: 0 | sampled posterior value = -3.573065328116984
# best = -3.0690040918540054
# trial 1/5 | iteration 12/100
# picked category: 0 | sampled posterior value = -3.372261820953771
# best = -3.0690040918540054
# trial 1/5 | iteration 13/100
# picked category: 0 | sampled posterior value = -3.7808572695726457
# best = -3.0690040918540054
# trial 1/5 | iteration 14/100
# picked category: 0 | sampled posterior value = -4.122971996867932
# best = -3.0690040918540054
# trial 1/5 | iteration 15/100
# picked category: 0 | sampled posterior value = -3.993950364504112
# best = -3.0690040918540054
# trial 1/5 | iteration 16/100
# picked category: 0 | sampled posterior value = -3.530997449326414
# best = -3.0690040918540054
# trial 1/5 | iteration 17/100
# picked category: 0 | sampled posterior value = -3.7283037579483764
# best = -3.0690040918540054
# trial 1/5 | iteration 18/100
# picked category: 0 | sampled posterior value = -4.126727358527566
# best = -3.0690040918540054
# trial 1/5 | iteration 19/100
# picked category: 0 | sampled posterior value = -4.07660723629969
# best = -3.0690040918540054
# trial 1/5 | iteration 20/100
# picked category: 0 | sampled posterior value = -3.72159976830126
# best = -2.562626276972136
# trial 1/5 | iteration 21/100
# picked category: 0 | sampled posterior value = -3.7368246232943823
# best = -2.562626276972136
# trial 1/5 | iteration 22/100
# picked category: 0 | sampled posterior value = -3.8795989505240973
# best = -2.562626276972136
# trial 1/5 | iteration 23/100
# picked category: 0 | sampled posterior value = -3.5457819421472214
# best = -2.562626276972136
# trial 1/5 | iteration 24/100
# picked category: 0 | sampled posterior value = -3.6372564612477767
# best = -2.562626276972136
# trial 1/5 | iteration 25/100
# picked category: 0 | sampled posterior value = -3.376052274272106
# best = -2.562626276972136
# trial 1/5 | iteration 26/100
# picked category: 0 | sampled posterior value = -3.0916927884007044
# best = -2.562626276972136
# trial 1/5 | iteration 27/100
# picked category: 0 | sampled posterior value = -3.41015036242731
# best = -2.562626276972136
# trial 1/5 | iteration 28/100
# picked category: 0 | sampled posterior value = -3.491319511982697
# best = -2.562626276972136
# trial 1/5 | iteration 29/100
# picked category: 0 | sampled posterior value = -3.0904320122935607
# best = -2.562626276972136
# trial 1/5 | iteration 30/100
# picked category: 0 | sampled posterior value = -2.752117599960166
# best = -2.562626276972136
# trial 1/5 | iteration 31/100
# picked category: 0 | sampled posterior value = -3.1614573098272216
# best = -2.4236680453006128
# trial 1/5 | iteration 32/100
# picked category: 0 | sampled posterior value = -2.4663392777269753
# best = -2.4236680453006128
# trial 1/5 | iteration 33/100
# picked category: 0 | sampled posterior value = -2.6257324153605346
# best = -2.4236680453006128
# trial 1/5 | iteration 34/100
# picked category: 0 | sampled posterior value = -2.7697454162526607
# best = -2.4236680453006128
# trial 1/5 | iteration 35/100
# picked category: 0 | sampled posterior value = -3.2177573664254697
# best = -2.4236680453006128
# trial 1/5 | iteration 36/100
# picked category: 0 | sampled posterior value = -2.853711279650138
# best = -2.4236680453006128
# trial 1/5 | iteration 37/100
# picked category: 0 | sampled posterior value = -2.9886303448690574
# best = -2.4236680453006128
# trial 1/5 | iteration 38/100
# picked category: 0 | sampled posterior value = -2.7751038468009295
# best = -2.4236680453006128
# trial 1/5 | iteration 39/100
# picked category: 0 | sampled posterior value = -3.121717695786465
# best = -2.4236680453006128
# trial 1/5 | iteration 40/100
# picked category: 0 | sampled posterior value = -2.754499903450574
# best = -2.4236680453006128
# trial 1/5 | iteration 41/100
# picked category: 0 | sampled posterior value = -3.480482736878871
# best = -1.9522231009298783
# trial 1/5 | iteration 42/100
# picked category: 0 | sampled posterior value = -2.621337941713363
# best = -1.9522231009298783
# trial 1/5 | iteration 43/100
# picked category: 0 | sampled posterior value = -3.163950596236866
# best = -1.9522231009298783
# trial 1/5 | iteration 44/100
# picked category: 0 | sampled posterior value = -2.644605651676034
# best = -1.9522231009298783
# trial 1/5 | iteration 45/100
# picked category: 0 | sampled posterior value = -2.5213366201860996
# best = -1.9522231009298783
# trial 1/5 | iteration 46/100
# picked category: 0 | sampled posterior value = -2.4816647551555744
# best = -1.9522231009298783
# trial 1/5 | iteration 47/100
# picked category: 0 | sampled posterior value = -2.114480386135328
# best = -1.9522231009298783
# trial 1/5 | iteration 48/100
# picked category: 0 | sampled posterior value = -2.498949187899415
# best = -1.9522231009298783
# trial 1/5 | iteration 49/100
# picked category: 0 | sampled posterior value = -2.7564463103628
# best = -1.9522231009298783
# trial 1/5 | iteration 50/100
# picked category: 0 | sampled posterior value = -2.623205692667409
# best = -1.9522231009298783
# trial 1/5 | iteration 51/100
# picked category: 0 | sampled posterior value = -2.4220670004474436
# best = -1.9522231009298783
# trial 1/5 | iteration 52/100
# picked category: 0 | sampled posterior value = -2.649790500215326
# best = -1.9522231009298783
# trial 1/5 | iteration 53/100
# picked category: 0 | sampled posterior value = -2.560983443713588
# best = -1.9522231009298783
# trial 1/5 | iteration 54/100
# picked category: 0 | sampled posterior value = -2.3073108617888565
# best = -1.9522231009298783
# trial 1/5 | iteration 55/100
# picked category: 0 | sampled posterior value = -2.7775015985822473
# best = -1.9522231009298783
# trial 1/5 | iteration 56/100
# picked category: 0 | sampled posterior value = -2.569438413388026
# best = -1.9522231009298783
# trial 1/5 | iteration 57/100
# picked category: 0 | sampled posterior value = -2.584635947476923
# best = -1.817387317588239
# trial 1/5 | iteration 58/100
# picked category: 0 | sampled posterior value = -2.560221798183982
# best = -1.817387317588239
# trial 1/5 | iteration 59/100
# picked category: 0 | sampled posterior value = -2.4311301444027897
# best = -1.817387317588239
# trial 1/5 | iteration 60/100
# picked category: 0 | sampled posterior value = -2.4101358919301754
# best = -1.817387317588239
# trial 1/5 | iteration 61/100
# picked category: 0 | sampled posterior value = -2.343353956502788
# best = -1.817387317588239
# trial 1/5 | iteration 62/100
# picked category: 0 | sampled posterior value = -2.376093927540938
# best = -1.817387317588239
# trial 1/5 | iteration 63/100
# picked category: 0 | sampled posterior value = -1.9194385289559852
# best = -1.817387317588239
# trial 1/5 | iteration 64/100
# picked category: 0 | sampled posterior value = -2.2337703461824967
# best = -1.817387317588239
# trial 1/5 | iteration 65/100
# picked category: 0 | sampled posterior value = -2.549834296148309
# best = -1.817387317588239
# trial 1/5 | iteration 66/100
# picked category: 0 | sampled posterior value = -2.4347560202371015
# best = -1.817387317588239
# trial 1/5 | iteration 67/100
# picked category: 0 | sampled posterior value = -2.4791146590305058
# best = -1.817387317588239
# trial 1/5 | iteration 68/100
# picked category: 0 | sampled posterior value = -2.54985208718634
# best = -1.817387317588239
# trial 1/5 | iteration 69/100
# picked category: 0 | sampled posterior value = -2.4745842423398376
# best = -1.817387317588239
# trial 1/5 | iteration 70/100
# picked category: 0 | sampled posterior value = -2.4789949712814403
# best = -1.817387317588239
# trial 1/5 | iteration 71/100
# picked category: 0 | sampled posterior value = -2.2715752575914143
# best = -1.817387317588239
# trial 1/5 | iteration 72/100
# picked category: 0 | sampled posterior value = -2.512918672531424
# best = -1.817387317588239
# trial 1/5 | iteration 73/100
# picked category: 0 | sampled posterior value = -2.1537749639472112
# best = -1.817387317588239
# trial 1/5 | iteration 74/100
# picked category: 0 | sampled posterior value = -1.9939774821661322
# best = -1.817387317588239
# trial 1/5 | iteration 75/100
# picked category: 0 | sampled posterior value = -2.8229553381138035
# best = -1.817387317588239
# trial 1/5 | iteration 76/100
# picked category: 0 | sampled posterior value = -2.6255842689035593
# best = -1.817387317588239
# trial 1/5 | iteration 77/100
# picked category: 0 | sampled posterior value = -2.3859116798405617
# best = -1.6397846426472644
# trial 1/5 | iteration 78/100
# picked category: 0 | sampled posterior value = -2.263202602634861
# best = -1.6397846426472644
# trial 1/5 | iteration 79/100
# picked category: 0 | sampled posterior value = -2.4104862086836194
# best = -1.6397846426472644
# trial 1/5 | iteration 80/100
# picked category: 0 | sampled posterior value = -2.3721676031410874
# best = -1.6397846426472644
# trial 1/5 | iteration 81/100
# picked category: 0 | sampled posterior value = -2.3236687547824744
# best = -1.6397846426472644
# trial 1/5 | iteration 82/100
# picked category: 0 | sampled posterior value = -2.20842789289893
# best = -1.6397846426472644
# trial 1/5 | iteration 83/100
# picked category: 0 | sampled posterior value = -1.922897853368197
# best = -1.6397846426472644
# trial 1/5 | iteration 84/100
# picked category: 0 | sampled posterior value = -2.467882076798517
# best = -1.6397846426472644
# trial 1/5 | iteration 85/100
# picked category: 0 | sampled posterior value = -2.5611197184131105
# best = -1.6397846426472644
# trial 1/5 | iteration 86/100
# picked category: 0 | sampled posterior value = -2.2513578185008964
# best = -1.6397846426472644
# trial 1/5 | iteration 87/100
# picked category: 0 | sampled posterior value = -2.2778107316653435
# best = -1.6397846426472644
# trial 1/5 | iteration 88/100
# picked category: 0 | sampled posterior value = -2.3747369812597072
# best = -0.9496098377844722
# trial 1/5 | iteration 89/100
# picked category: 0 | sampled posterior value = -2.408174935156796
# best = -0.9496098377844722
# trial 1/5 | iteration 90/100
# picked category: 0 | sampled posterior value = -2.3870285111662337
# best = -0.9496098377844722
# trial 1/5 | iteration 91/100
# picked category: 0 | sampled posterior value = -2.074238806935798
# best = -0.9496098377844722
# trial 1/5 | iteration 92/100
# picked category: 0 | sampled posterior value = -2.4044789099663415
# best = -0.9496098377844722
# trial 1/5 | iteration 93/100
# picked category: 0 | sampled posterior value = -2.0699211085502913
# best = -0.9496098377844722
# trial 1/5 | iteration 94/100
# picked category: 0 | sampled posterior value = -1.9562962943423983
# best = -0.9496098377844722
# trial 1/5 | iteration 95/100
# picked category: 0 | sampled posterior value = -1.8413166802002985
# best = -0.9496098377844722
# trial 1/5 | iteration 96/100
# picked category: 0 | sampled posterior value = -1.874466057731653
# best = -0.9496098377844722
# trial 1/5 | iteration 97/100
# picked category: 0 | sampled posterior value = -2.5591632605933543
# best = -0.9496098377844722
# trial 1/5 | iteration 98/100
# picked category: 0 | sampled posterior value = -2.2120881435220086
# best = -0.9496098377844722
# trial 1/5 | iteration 99/100
# picked category: 0 | sampled posterior value = -1.7283460955192533
# best = -0.9496098377844722
# trial 1/5 | iteration 100/100
# picked category: 0 | sampled posterior value = -2.0419200751521367
# best = -0.9496098377844722
# trial 2/5 | iteration 1/100
# picked category: 0 | sampled posterior value = -2.800297802513383
# best = -3.3938920453452757
# trial 2/5 | iteration 2/100
# picked category: 0 | sampled posterior value = -2.688136259220285
# best = -3.3938920453452757
# trial 2/5 | iteration 3/100
# picked category: 0 | sampled posterior value = -2.8409779331954637
# best = -3.3938920453452757
# trial 2/5 | iteration 4/100
# picked category: 0 | sampled posterior value = -3.125819384641997
# best = -3.3938920453452757
# trial 2/5 | iteration 5/100
# picked category: 0 | sampled posterior value = -2.7548407091156255
# best = -3.317697700809259
# trial 2/5 | iteration 6/100
# picked category: 0 | sampled posterior value = -2.8339912344149596
# best = -3.317697700809259
# trial 2/5 | iteration 7/100
# picked category: 0 | sampled posterior value = -2.78501414455915
# best = -3.1977698109934214
# trial 2/5 | iteration 8/100
# picked category: 0 | sampled posterior value = -2.924231644741528
# best = -3.1977698109934214
# trial 2/5 | iteration 9/100
# picked category: 0 | sampled posterior value = -2.353296303252276
# best = -3.1977698109934214
# trial 2/5 | iteration 10/100
# picked category: 0 | sampled posterior value = -3.270138992190903
# best = -3.1977698109934214
# trial 2/5 | iteration 11/100
# picked category: 0 | sampled posterior value = -3.054717017713539
# best = -3.1977698109934214
# trial 2/5 | iteration 12/100
# picked category: 0 | sampled posterior value = -3.091240093551145
# best = -3.1977698109934214
# trial 2/5 | iteration 13/100
# picked category: 0 | sampled posterior value = -2.6492164379425147
# best = -2.9881214134529306
# trial 2/5 | iteration 14/100
# picked category: 0 | sampled posterior value = -2.8762500505112523
# best = -2.9881214134529306
# trial 2/5 | iteration 15/100
# picked category: 0 | sampled posterior value = -2.9024713082980034
# best = -2.9881214134529306
# trial 2/5 | iteration 16/100
# picked category: 0 | sampled posterior value = -2.564055241442807
# best = -2.9881214134529306
# trial 2/5 | iteration 17/100
# picked category: 0 | sampled posterior value = -3.027885502465551
# best = -1.8212287127669708
# trial 2/5 | iteration 18/100
# picked category: 0 | sampled posterior value = -2.4020081499134167
# best = -1.8212287127669708
# trial 2/5 | iteration 19/100
# picked category: 0 | sampled posterior value = -2.3971069570552825
# best = -1.8212287127669708
# trial 2/5 | iteration 20/100
# picked category: 0 | sampled posterior value = -2.3836237017270663
# best = -1.8212287127669708
# trial 2/5 | iteration 21/100
# picked category: 0 | sampled posterior value = -2.570519909827164
# best = -1.8212287127669708
# trial 2/5 | iteration 22/100
# picked category: 0 | sampled posterior value = -2.814482186700183
# best = -1.8212287127669708
# trial 2/5 | iteration 23/100
# picked category: 0 | sampled posterior value = -2.840893794348662
# best = -1.8212287127669708
# trial 2/5 | iteration 24/100
# picked category: 0 | sampled posterior value = -2.43629941780117
# best = -1.8212287127669708
# trial 2/5 | iteration 25/100
# picked category: 0 | sampled posterior value = -2.453820346768102
# best = -1.8212287127669708
# trial 2/5 | iteration 26/100
# picked category: 0 | sampled posterior value = -2.532719930129419
# best = -1.8212287127669708
# trial 2/5 | iteration 27/100
# picked category: 0 | sampled posterior value = -2.4360274821802994
# best = -1.8212287127669708
# trial 2/5 | iteration 28/100
# picked category: 0 | sampled posterior value = -2.2226972553442534
# best = -1.8212287127669708
# trial 2/5 | iteration 29/100
# picked category: 0 | sampled posterior value = -2.2044238402249254
# best = -1.747716508467907
# trial 2/5 | iteration 30/100
# picked category: 0 | sampled posterior value = -2.197665817956587
# best = -1.747716508467907
# trial 2/5 | iteration 31/100
# picked category: 0 | sampled posterior value = -2.148902761869281
# best = -1.747716508467907
# trial 2/5 | iteration 32/100
# picked category: 0 | sampled posterior value = -2.478749558794645
# best = -1.747716508467907
# trial 2/5 | iteration 33/100
# picked category: 0 | sampled posterior value = -2.0708429989864348
# best = -1.747716508467907
# trial 2/5 | iteration 34/100
# picked category: 0 | sampled posterior value = -2.058604907549113
# best = -1.747716508467907
# trial 2/5 | iteration 35/100
# picked category: 0 | sampled posterior value = -2.5003616918530147
# best = -1.747716508467907
# trial 2/5 | iteration 36/100
# picked category: 0 | sampled posterior value = -2.6448684803404694
# best = -1.747716508467907
# trial 2/5 | iteration 37/100
# picked category: 0 | sampled posterior value = -2.253592823885592
# best = -1.747716508467907
# trial 2/5 | iteration 38/100
# picked category: 0 | sampled posterior value = -2.6473122743230553
# best = -1.747716508467907
# trial 2/5 | iteration 39/100
# picked category: 0 | sampled posterior value = -2.169559791043734
# best = -1.5569241480647524
# trial 2/5 | iteration 40/100
# picked category: 0 | sampled posterior value = -2.939407212049935
# best = -1.5569241480647524
# trial 2/5 | iteration 41/100
# picked category: 0 | sampled posterior value = -2.121820428121799
# best = -1.5569241480647524
# trial 2/5 | iteration 42/100
# picked category: 0 | sampled posterior value = -2.4174957953297156
# best = -1.5569241480647524
# trial 2/5 | iteration 43/100
# picked category: 0 | sampled posterior value = -2.162252728572069
# best = -1.5569241480647524
# trial 2/5 | iteration 44/100
# picked category: 0 | sampled posterior value = -1.8646726373238878
# best = -1.5569241480647524
# trial 2/5 | iteration 45/100
# picked category: 0 | sampled posterior value = -2.09859917315927
# best = -1.5569241480647524
# trial 2/5 | iteration 46/100
# picked category: 0 | sampled posterior value = -2.5217679793570476
# best = -1.5569241480647524
# trial 2/5 | iteration 47/100
# picked category: 0 | sampled posterior value = -2.4182983271559424
# best = -1.5569241480647524
# trial 2/5 | iteration 48/100
# picked category: 0 | sampled posterior value = -1.9428298188942918
# best = -1.4599267322586376
# trial 2/5 | iteration 49/100
# picked category: 0 | sampled posterior value = -2.4718363994323327
# best = -1.4599267322586376
# trial 2/5 | iteration 50/100
# picked category: 0 | sampled posterior value = -1.7577913942606498
# best = -1.4599267322586376
# trial 2/5 | iteration 51/100
# picked category: 0 | sampled posterior value = -2.184687457069013
# best = -1.4599267322586376
# trial 2/5 | iteration 52/100
# picked category: 0 | sampled posterior value = -2.1333256928596387
# best = -1.4599267322586376
# trial 2/5 | iteration 53/100
# picked category: 0 | sampled posterior value = -2.0802810924031414
# best = -1.4599267322586376
# trial 2/5 | iteration 54/100
# picked category: 0 | sampled posterior value = -2.3158748720064986
# best = -1.4599267322586376
# trial 2/5 | iteration 55/100
# picked category: 0 | sampled posterior value = -2.147220579902074
# best = -1.4599267322586376
# trial 2/5 | iteration 56/100
# picked category: 0 | sampled posterior value = -2.1590276423771395
# best = -1.4599267322586376
# trial 2/5 | iteration 57/100
# picked category: 0 | sampled posterior value = -1.0015202251290223
# best = -0.8243766720149179
# trial 2/5 | iteration 58/100
# picked category: 0 | sampled posterior value = -2.1462098169672044
# best = -0.8243766720149179
# trial 2/5 | iteration 59/100
# picked category: 0 | sampled posterior value = -2.124694417004744
# best = -0.8243766720149179
# trial 2/5 | iteration 60/100
# picked category: 0 | sampled posterior value = -1.9686390487383587
# best = -0.8243766720149179
# trial 2/5 | iteration 61/100
# picked category: 0 | sampled posterior value = -2.1471151978989167
# best = -0.8243766720149179
# trial 2/5 | iteration 62/100
# picked category: 0 | sampled posterior value = -2.0095107194679755
# best = -0.8243766720149179
# trial 2/5 | iteration 63/100
# picked category: 0 | sampled posterior value = -2.182166836772192
# best = -0.8243766720149179
# trial 2/5 | iteration 64/100
# picked category: 0 | sampled posterior value = -2.2094768038503747
# best = -0.8243766720149179
# trial 2/5 | iteration 65/100
# picked category: 0 | sampled posterior value = -1.821378820820021
# best = -0.8243766720149179
# trial 2/5 | iteration 66/100
# picked category: 0 | sampled posterior value = -2.498739786637983
# best = -0.8243766720149179
# trial 2/5 | iteration 67/100
# picked category: 0 | sampled posterior value = -2.220247837261217
# best = -0.8243766720149179
# trial 2/5 | iteration 68/100
# picked category: 0 | sampled posterior value = -1.857990574603881
# best = -0.8243766720149179
# trial 2/5 | iteration 69/100
# picked category: 0 | sampled posterior value = -1.9498149004525627
# best = -0.8243766720149179
# trial 2/5 | iteration 70/100
# picked category: 0 | sampled posterior value = -2.3880113695636114
# best = -0.8243766720149179
# trial 2/5 | iteration 71/100
# picked category: 0 | sampled posterior value = -2.1275194071830716
# best = -0.8243766720149179
# trial 2/5 | iteration 72/100
# picked category: 0 | sampled posterior value = -1.740067683669304
# best = -0.8243766720149179
# trial 2/5 | iteration 73/100
# picked category: 0 | sampled posterior value = -1.9550644505701833
# best = -0.8243766720149179
# trial 2/5 | iteration 74/100
# picked category: 0 | sampled posterior value = -1.967864526299613
# best = -0.8243766720149179
# trial 2/5 | iteration 75/100
# picked category: 0 | sampled posterior value = -1.9194171474220545
# best = -0.8243766720149179
# trial 2/5 | iteration 76/100
# picked category: 0 | sampled posterior value = -1.3741782430686778
# best = -0.6368514951153519
# trial 2/5 | iteration 77/100
# picked category: 0 | sampled posterior value = -2.331915646345614
# best = -0.6368514951153519
# trial 2/5 | iteration 78/100
# picked category: 0 | sampled posterior value = -1.9477916319624042
# best = -0.6368514951153519
# trial 2/5 | iteration 79/100
# picked category: 0 | sampled posterior value = -1.7030537818973432
# best = -0.6368514951153519
# trial 2/5 | iteration 80/100
# picked category: 0 | sampled posterior value = -1.4066438204150384
# best = -0.6368514951153519
# trial 2/5 | iteration 81/100
# picked category: 0 | sampled posterior value = -1.7603081332651893
# best = -0.6368514951153519
# trial 2/5 | iteration 82/100
# picked category: 0 | sampled posterior value = -2.2366856395545254
# best = -0.6368514951153519
# trial 2/5 | iteration 83/100
# picked category: 0 | sampled posterior value = -1.3336396819647802
# best = -0.6368514951153519
# trial 2/5 | iteration 84/100
# picked category: 0 | sampled posterior value = -1.976907065127547
# best = -0.6368514951153519
# trial 2/5 | iteration 85/100
# picked category: 0 | sampled posterior value = -1.8282295159544812
# best = -0.6368514951153519
# trial 2/5 | iteration 86/100
# picked category: 0 | sampled posterior value = -2.48061589741344
# best = -0.6368514951153519
# trial 2/5 | iteration 87/100
# picked category: 0 | sampled posterior value = -2.1775847021185895
# best = -0.6368514951153519
# trial 2/5 | iteration 88/100
# picked category: 0 | sampled posterior value = -1.3849999052416102
# best = -0.6368514951153519
# trial 2/5 | iteration 89/100
# picked category: 0 | sampled posterior value = -2.372330314839186
# best = -0.6368514951153519
# trial 2/5 | iteration 90/100
# picked category: 0 | sampled posterior value = -2.04881887830009
# best = -0.6368514951153519
# trial 2/5 | iteration 91/100
# picked category: 0 | sampled posterior value = -1.4752144970921386
# best = -0.6368514951153519
# trial 2/5 | iteration 92/100
# picked category: 0 | sampled posterior value = -1.8834501329230107
# best = -0.6368514951153519
# trial 2/5 | iteration 93/100
# picked category: 0 | sampled posterior value = -1.4791378184803659
# best = -0.6368514951153519
# trial 2/5 | iteration 94/100
# picked category: 0 | sampled posterior value = -2.1024035469440197
# best = -0.6368514951153519
# trial 2/5 | iteration 95/100
# picked category: 0 | sampled posterior value = -1.8603631992837535
# best = -0.6368514951153519
# trial 2/5 | iteration 96/100
# picked category: 0 | sampled posterior value = -2.106569239738862
# best = -0.6368514951153519
# trial 2/5 | iteration 97/100
# picked category: 0 | sampled posterior value = -1.5375185393818402
# best = -0.6368514951153519
# trial 2/5 | iteration 98/100
# picked category: 0 | sampled posterior value = -2.3128838351415273
# best = -0.6368514951153519
# trial 2/5 | iteration 99/100
# picked category: 0 | sampled posterior value = -1.6578902885320614
# best = -0.6368514951153519
# trial 2/5 | iteration 100/100
# picked category: 0 | sampled posterior value = -2.279744856781707
# best = -0.6368514951153519
# trial 3/5 | iteration 1/100
# picked category: 0 | sampled posterior value = -3.129279460327104
# best = -3.686686645167779
# trial 3/5 | iteration 2/100
# picked category: 0 | sampled posterior value = -3.6310969434899323
# best = -3.4557861180628007
# trial 3/5 | iteration 3/100
# picked category: 0 | sampled posterior value = -3.030597141955696
# best = -3.4557861180628007
# trial 3/5 | iteration 4/100
# picked category: 0 | sampled posterior value = -3.1591259163967225
# best = -3.4557861180628007
# trial 3/5 | iteration 5/100
# picked category: 0 | sampled posterior value = -3.6169234450504084
# best = -3.4557861180628007
# trial 3/5 | iteration 6/100
# picked category: 0 | sampled posterior value = -3.373523508651127
# best = -3.4557861180628007
# trial 3/5 | iteration 7/100
# picked category: 0 | sampled posterior value = -3.367235289256617
# best = -3.4557861180628007
# trial 3/5 | iteration 8/100
# picked category: 0 | sampled posterior value = -3.3217427248567994
# best = -3.4557861180628007
# trial 3/5 | iteration 9/100
# picked category: 0 | sampled posterior value = -3.131830402793108
# best = -3.4557861180628007
# trial 3/5 | iteration 10/100
# picked category: 0 | sampled posterior value = -3.0769419184198377
# best = -2.770464527092799
# trial 3/5 | iteration 11/100
# picked category: 0 | sampled posterior value = -2.942393878998538
# best = -2.770464527092799
# trial 3/5 | iteration 12/100
# picked category: 0 | sampled posterior value = -3.0450717857094274
# best = -2.770464527092799
# trial 3/5 | iteration 13/100
# picked category: 0 | sampled posterior value = -2.9556439743790643
# best = -2.395761279470229
# trial 3/5 | iteration 14/100
# picked category: 0 | sampled posterior value = -2.7396930846647045
# best = -2.395761279470229
# trial 3/5 | iteration 15/100
# picked category: 0 | sampled posterior value = -2.7814116799769164
# best = -2.395761279470229
# trial 3/5 | iteration 16/100
# picked category: 0 | sampled posterior value = -2.9103180503569352
# best = -2.395761279470229
# trial 3/5 | iteration 17/100
# picked category: 0 | sampled posterior value = -2.7577139177714125
# best = -2.395761279470229
# trial 3/5 | iteration 18/100
# picked category: 0 | sampled posterior value = -2.680074942361756
# best = -2.395761279470229
# trial 3/5 | iteration 19/100
# picked category: 0 | sampled posterior value = -2.202697422792444
# best = -2.395761279470229
# trial 3/5 | iteration 20/100
# picked category: 0 | sampled posterior value = -2.8062917972723826
# best = -2.395761279470229
# trial 3/5 | iteration 21/100
# picked category: 0 | sampled posterior value = -2.6289786972493023
# best = -2.395761279470229
# trial 3/5 | iteration 22/100
# picked category: 0 | sampled posterior value = -2.7109870515029217
# best = -2.395761279470229
# trial 3/5 | iteration 23/100
# picked category: 0 | sampled posterior value = -2.606025709969021
# best = -2.395761279470229
# trial 3/5 | iteration 24/100
# picked category: 0 | sampled posterior value = -2.546847829128345
# best = -2.395761279470229
# trial 3/5 | iteration 25/100
# picked category: 0 | sampled posterior value = -2.919409482771475
# best = -2.395761279470229
# trial 3/5 | iteration 26/100
# picked category: 0 | sampled posterior value = -2.7159655914144496
# best = -2.395761279470229
# trial 3/5 | iteration 27/100
# picked category: 0 | sampled posterior value = -2.876286154196765
# best = -2.395761279470229
# trial 3/5 | iteration 28/100
# picked category: 0 | sampled posterior value = -2.477200711864798
# best = -2.395761279470229
# trial 3/5 | iteration 29/100
# picked category: 0 | sampled posterior value = -2.632845493459565
# best = -2.3810651664396763
# trial 3/5 | iteration 30/100
# picked category: 0 | sampled posterior value = -2.6131340826144847
# best = -2.3810651664396763
# trial 3/5 | iteration 31/100
# picked category: 0 | sampled posterior value = -2.219658387478262
# best = -2.3810651664396763
# trial 3/5 | iteration 32/100
# picked category: 0 | sampled posterior value = -2.464050066986812
# best = -2.3810651664396763
# trial 3/5 | iteration 33/100
# picked category: 0 | sampled posterior value = -2.3154186537994397
# best = -2.3810651664396763
# trial 3/5 | iteration 34/100
# picked category: 0 | sampled posterior value = -2.87369855555977
# best = -2.3810651664396763
# trial 3/5 | iteration 35/100
# picked category: 0 | sampled posterior value = -2.6795444682011054
# best = -2.0096004521642716
# trial 3/5 | iteration 36/100
# picked category: 0 | sampled posterior value = -2.511950356795657
# best = -2.0096004521642716
# trial 3/5 | iteration 37/100
# picked category: 0 | sampled posterior value = -2.703699183208415
# best = -2.0096004521642716
# trial 3/5 | iteration 38/100
# picked category: 0 | sampled posterior value = -2.6661646224768853
# best = -2.0096004521642716
# trial 3/5 | iteration 39/100
# picked category: 0 | sampled posterior value = -2.759252874951908
# best = -2.0096004521642716
# trial 3/5 | iteration 40/100
# picked category: 0 | sampled posterior value = -2.554802832298399
# best = -2.0096004521642716
# trial 3/5 | iteration 41/100
# picked category: 0 | sampled posterior value = -2.2399506943630696
# best = -2.0096004521642716
# trial 3/5 | iteration 42/100
# picked category: 0 | sampled posterior value = -2.253810871544365
# best = -2.0096004521642716
# trial 3/5 | iteration 43/100
# picked category: 0 | sampled posterior value = -2.642526747725844
# best = -2.0096004521642716
# trial 3/5 | iteration 44/100
# picked category: 0 | sampled posterior value = -2.6237087750332595
# best = -2.0096004521642716
# trial 3/5 | iteration 45/100
# picked category: 0 | sampled posterior value = -2.9749592730723915
# best = -2.0096004521642716
# trial 3/5 | iteration 46/100
# picked category: 0 | sampled posterior value = -2.533812528569439
# best = -2.0096004521642716
# trial 3/5 | iteration 47/100
# picked category: 0 | sampled posterior value = -1.8488173883920136
# best = -1.5702764574767731
# trial 3/5 | iteration 48/100
# picked category: 0 | sampled posterior value = -2.1349503018155347
# best = -1.3184074424983554
# trial 3/5 | iteration 49/100
# picked category: 0 | sampled posterior value = -2.513560151987514
# best = -1.3184074424983554
# trial 3/5 | iteration 50/100
# picked category: 0 | sampled posterior value = -2.4084159535053447
# best = -1.3184074424983554
# trial 3/5 | iteration 51/100
# picked category: 0 | sampled posterior value = -2.503226115892976
# best = -1.3184074424983554
# trial 3/5 | iteration 52/100
# picked category: 0 | sampled posterior value = -2.2837558454603837
# best = -1.3184074424983554
# trial 3/5 | iteration 53/100
# picked category: 0 | sampled posterior value = -2.500457646226403
# best = -1.3184074424983554
# trial 3/5 | iteration 54/100
# picked category: 0 | sampled posterior value = -1.9703435011218469
# best = -1.3184074424983554
# trial 3/5 | iteration 55/100
# picked category: 0 | sampled posterior value = -2.3243606739453515
# best = -1.3184074424983554
# trial 3/5 | iteration 56/100
# picked category: 0 | sampled posterior value = -2.322066487477878
# best = -1.3184074424983554
# trial 3/5 | iteration 57/100
# picked category: 0 | sampled posterior value = -2.2182230490573467
# best = -1.3184074424983554
# trial 3/5 | iteration 58/100
# picked category: 0 | sampled posterior value = -2.2538010554467833
# best = -1.3184074424983554
# trial 3/5 | iteration 59/100
# picked category: 0 | sampled posterior value = -2.3888228257105566
# best = -1.3184074424983554
# trial 3/5 | iteration 60/100
# picked category: 0 | sampled posterior value = -1.9679293146997416
# best = -0.9501641924838862
# trial 3/5 | iteration 61/100
# picked category: 0 | sampled posterior value = -2.420895074658373
# best = -0.9501641924838862
# trial 3/5 | iteration 62/100
# picked category: 0 | sampled posterior value = -1.9476115952543824
# best = -0.9501641924838862
# trial 3/5 | iteration 63/100
# picked category: 0 | sampled posterior value = -1.559499147926482
# best = -0.9501641924838862
# trial 3/5 | iteration 64/100
# picked category: 0 | sampled posterior value = -2.1153122235702084
# best = -0.9501641924838862
# trial 3/5 | iteration 65/100
# picked category: 0 | sampled posterior value = -2.497002928790976
# best = -0.9501641924838862
# trial 3/5 | iteration 66/100
# picked category: 0 | sampled posterior value = -1.8356581261973133
# best = -0.9501641924838862
# trial 3/5 | iteration 67/100
# picked category: 0 | sampled posterior value = -2.2794496468779655
# best = -0.9501641924838862
# trial 3/5 | iteration 68/100
# picked category: 0 | sampled posterior value = -2.1347810990624176
# best = -0.9501641924838862
# trial 3/5 | iteration 69/100
# picked category: 0 | sampled posterior value = -2.205253060350821
# best = -0.9501641924838862
# trial 3/5 | iteration 70/100
# picked category: 0 | sampled posterior value = -1.8214997370268988
# best = -0.9501641924838862
# trial 3/5 | iteration 71/100
# picked category: 0 | sampled posterior value = -1.8575912002461015
# best = -0.9501641924838862
# trial 3/5 | iteration 72/100
# picked category: 0 | sampled posterior value = -1.8313496839081191
# best = -0.9501641924838862
# trial 3/5 | iteration 73/100
# picked category: 0 | sampled posterior value = -2.2783024407932744
# best = -0.9501641924838862
# trial 3/5 | iteration 74/100
# picked category: 0 | sampled posterior value = -2.1341573152507585
# best = -0.9501641924838862
# trial 3/5 | iteration 75/100
# picked category: 0 | sampled posterior value = -2.627452109647984
# best = -0.9501641924838862
# trial 3/5 | iteration 76/100
# picked category: 0 | sampled posterior value = -2.4643505217038633
# best = -0.9501641924838862
# trial 3/5 | iteration 77/100
# picked category: 0 | sampled posterior value = -2.1522065698542705
# best = -0.9501641924838862
# trial 3/5 | iteration 78/100
# picked category: 0 | sampled posterior value = -1.4356209070393744
# best = -0.9501641924838862
# trial 3/5 | iteration 79/100
# picked category: 0 | sampled posterior value = -1.9213084912861838
# best = -0.9501641924838862
# trial 3/5 | iteration 80/100
# picked category: 0 | sampled posterior value = -1.953865520570188
# best = -0.9501641924838862
# trial 3/5 | iteration 81/100
# picked category: 0 | sampled posterior value = -2.285092119850847
# best = -0.9501641924838862
# trial 3/5 | iteration 82/100
# picked category: 0 | sampled posterior value = -2.272504383318437
# best = -0.9501641924838862
# trial 3/5 | iteration 83/100
# picked category: 0 | sampled posterior value = -1.909472246306389
# best = -0.9501641924838862
# trial 3/5 | iteration 84/100
# picked category: 0 | sampled posterior value = -1.5499412593447726
# best = -0.9501641924838862
# trial 3/5 | iteration 85/100
# picked category: 0 | sampled posterior value = -1.9400836148565803
# best = -0.9501641924838862
# trial 3/5 | iteration 86/100
# picked category: 0 | sampled posterior value = -1.7866841265623201
# best = -0.9501641924838862
# trial 3/5 | iteration 87/100
# picked category: 0 | sampled posterior value = -2.4229358324495025
# best = -0.9501641924838862
# trial 3/5 | iteration 88/100
# picked category: 0 | sampled posterior value = -1.7410351570149314
# best = -0.8087879689722226
# trial 3/5 | iteration 89/100
# picked category: 0 | sampled posterior value = -1.4359724678637438
# best = -0.8087879689722226
# trial 3/5 | iteration 90/100
# picked category: 0 | sampled posterior value = -2.4372256659247684
# best = -0.8087879689722226
# trial 3/5 | iteration 91/100
# picked category: 0 | sampled posterior value = -1.7722477659108389
# best = -0.8087879689722226
# trial 3/5 | iteration 92/100
# picked category: 0 | sampled posterior value = -2.4329990004155913
# best = -0.8087879689722226
# trial 3/5 | iteration 93/100
# picked category: 0 | sampled posterior value = -1.5463175464086634
# best = -0.8087879689722226
# trial 3/5 | iteration 94/100
# picked category: 0 | sampled posterior value = -2.646272168475555
# best = -0.8087879689722226
# trial 3/5 | iteration 95/100
# picked category: 0 | sampled posterior value = -0.96265438881927
# best = -0.8087879689722226
# trial 3/5 | iteration 96/100
# picked category: 0 | sampled posterior value = -1.841527071125826
# best = -0.8087879689722226
# trial 3/5 | iteration 97/100
# picked category: 0 | sampled posterior value = -2.32527931179851
# best = -0.8087879689722226
# trial 3/5 | iteration 98/100
# picked category: 0 | sampled posterior value = -1.8403608393122746
# best = -0.8087879689722226
# trial 3/5 | iteration 99/100
# picked category: 0 | sampled posterior value = -2.1539604216509534
# best = -0.8087879689722226
# trial 3/5 | iteration 100/100
# picked category: 0 | sampled posterior value = -2.401408970136186
# best = -0.8087879689722226
# trial 4/5 | iteration 1/100
# picked category: 0 | sampled posterior value = -4.515431895319091
# best = -4.333852725748674
# trial 4/5 | iteration 2/100
# picked category: 0 | sampled posterior value = -3.857978490329934
# best = -3.9016399381881652
# trial 4/5 | iteration 3/100
# picked category: 0 | sampled posterior value = -2.9463452100006533
# best = -3.460131234624708
# trial 4/5 | iteration 4/100
# picked category: 0 | sampled posterior value = -3.4820525530502895
# best = -3.460131234624708
# trial 4/5 | iteration 5/100
# picked category: 0 | sampled posterior value = -3.2842384535184914
# best = -3.460131234624708
# trial 4/5 | iteration 6/100
# picked category: 0 | sampled posterior value = -3.6947297018482885
# best = -3.460131234624708
# trial 4/5 | iteration 7/100
# picked category: 0 | sampled posterior value = -3.5533233083495133
# best = -3.460131234624708
# trial 4/5 | iteration 8/100
# picked category: 0 | sampled posterior value = -3.3975421475731142
# best = -3.460131234624708
# trial 4/5 | iteration 9/100
# picked category: 0 | sampled posterior value = -3.530129594719906
# best = -3.460131234624708
# trial 4/5 | iteration 10/100
# picked category: 0 | sampled posterior value = -3.5606947733058636
# best = -3.460131234624708
# trial 4/5 | iteration 11/100
# picked category: 0 | sampled posterior value = -3.098283497257655
# best = -3.293812453328979
# trial 4/5 | iteration 12/100
# picked category: 0 | sampled posterior value = -3.3755998507868474
# best = -3.293812453328979
# trial 4/5 | iteration 13/100
# picked category: 0 | sampled posterior value = -2.9259065792662797
# best = -3.293812453328979
# trial 4/5 | iteration 14/100
# picked category: 0 | sampled posterior value = -3.0894932570894795
# best = -3.293812453328979
# trial 4/5 | iteration 15/100
# picked category: 0 | sampled posterior value = -2.6308738286430957
# best = -3.293812453328979
# trial 4/5 | iteration 16/100
# picked category: 0 | sampled posterior value = -3.0378279881646715
# best = -2.4693765144965316
# trial 4/5 | iteration 17/100
# picked category: 0 | sampled posterior value = -2.5555945644466505
# best = -1.6385138638481114
# trial 4/5 | iteration 18/100
# picked category: 0 | sampled posterior value = -2.452092797394595
# best = -1.6385138638481114
# trial 4/5 | iteration 19/100
# picked category: 0 | sampled posterior value = -2.610581731896751
# best = -1.6385138638481114
# trial 4/5 | iteration 20/100
# picked category: 0 | sampled posterior value = -2.576712538047353
# best = -1.6385138638481114
# trial 4/5 | iteration 21/100
# picked category: 0 | sampled posterior value = -2.692715669157059
# best = -1.6385138638481114
# trial 4/5 | iteration 22/100
# picked category: 0 | sampled posterior value = -2.7068600553142494
# best = -1.6385138638481114
# trial 4/5 | iteration 23/100
# picked category: 0 | sampled posterior value = -2.5479386439472607
# best = -1.6385138638481114
# trial 4/5 | iteration 24/100
# picked category: 0 | sampled posterior value = -2.476364023813122
# best = -1.6385138638481114
# trial 4/5 | iteration 25/100
# picked category: 0 | sampled posterior value = -2.64924449501311
# best = -1.6385138638481114
# trial 4/5 | iteration 26/100
# picked category: 0 | sampled posterior value = -2.43594600482228
# best = -1.6385138638481114
# trial 4/5 | iteration 27/100
# picked category: 0 | sampled posterior value = -2.310463143752452
# best = -1.6385138638481114
# trial 4/5 | iteration 28/100
# picked category: 0 | sampled posterior value = -2.6879898257801216
# best = -1.6385138638481114
# trial 4/5 | iteration 29/100
# picked category: 0 | sampled posterior value = -2.2586393238492444
# best = -1.6385138638481114
# trial 4/5 | iteration 30/100
# picked category: 0 | sampled posterior value = -2.6459184445822306
# best = -1.6385138638481114
# trial 4/5 | iteration 31/100
# picked category: 0 | sampled posterior value = -1.6804900975607466
# best = -1.6385138638481114
# trial 4/5 | iteration 32/100
# picked category: 0 | sampled posterior value = -2.3474867652761824
# best = -1.6385138638481114
# trial 4/5 | iteration 33/100
# picked category: 0 | sampled posterior value = -2.7504328350879295
# best = -1.6385138638481114
# trial 4/5 | iteration 34/100
# picked category: 0 | sampled posterior value = -2.2997742944706525
# best = -1.6385138638481114
# trial 4/5 | iteration 35/100
# picked category: 0 | sampled posterior value = -2.57928233169441
# best = -1.6385138638481114
# trial 4/5 | iteration 36/100
# picked category: 0 | sampled posterior value = -2.3944043721785775
# best = -1.6385138638481114
# trial 4/5 | iteration 37/100
# picked category: 0 | sampled posterior value = -2.3160224344915146
# best = -1.6385138638481114
# trial 4/5 | iteration 38/100
# picked category: 0 | sampled posterior value = -2.716616217363014
# best = -1.6385138638481114
# trial 4/5 | iteration 39/100
# picked category: 0 | sampled posterior value = -2.431030949472998
# best = -1.6385138638481114
# trial 4/5 | iteration 40/100
# picked category: 0 | sampled posterior value = -2.4822620785735774
# best = -1.6385138638481114
# trial 4/5 | iteration 41/100
# picked category: 0 | sampled posterior value = -2.3205845406819954
# best = -1.6385138638481114
# trial 4/5 | iteration 42/100
# picked category: 0 | sampled posterior value = -2.2981269241247757
# best = -1.6385138638481114
# trial 4/5 | iteration 43/100
# picked category: 0 | sampled posterior value = -2.490074930889342
# best = -1.6385138638481114
# trial 4/5 | iteration 44/100
# picked category: 0 | sampled posterior value = -2.056796367279607
# best = -1.6385138638481114
# trial 4/5 | iteration 45/100
# picked category: 0 | sampled posterior value = -2.4266694170464436
# best = -1.6385138638481114
# trial 4/5 | iteration 46/100
# picked category: 0 | sampled posterior value = -2.220221423576699
# best = -1.6385138638481114
# trial 4/5 | iteration 47/100
# picked category: 0 | sampled posterior value = -2.6507748989711577
# best = -1.6385138638481114
# trial 4/5 | iteration 48/100
# picked category: 0 | sampled posterior value = -2.4976189533215374
# best = -1.6385138638481114
# trial 4/5 | iteration 49/100
# picked category: 0 | sampled posterior value = -2.6441184519784375
# best = -1.6385138638481114
# trial 4/5 | iteration 50/100
# picked category: 0 | sampled posterior value = -1.7973048978820092
# best = -1.2838231207137771
# trial 4/5 | iteration 51/100
# picked category: 0 | sampled posterior value = -2.2117378978840483
# best = -1.2838231207137771
# trial 4/5 | iteration 52/100
# picked category: 0 | sampled posterior value = -2.4920661245468656
# best = -1.2838231207137771
# trial 4/5 | iteration 53/100
# picked category: 0 | sampled posterior value = -2.4702062233507074
# best = -1.2838231207137771
# trial 4/5 | iteration 54/100
# picked category: 0 | sampled posterior value = -2.0890219208597327
# best = -1.2838231207137771
# trial 4/5 | iteration 55/100
# picked category: 0 | sampled posterior value = -2.298983070477559
# best = -1.2838231207137771
# trial 4/5 | iteration 56/100
# picked category: 0 | sampled posterior value = -2.387411055561469
# best = -1.2838231207137771
# trial 4/5 | iteration 57/100
# picked category: 0 | sampled posterior value = -2.5226604993361077
# best = -1.2838231207137771
# trial 4/5 | iteration 58/100
# picked category: 0 | sampled posterior value = -2.471320126405226
# best = -1.2838231207137771
# trial 4/5 | iteration 59/100
# picked category: 0 | sampled posterior value = -2.1421836607790565
# best = -1.2838231207137771
# trial 4/5 | iteration 60/100
# picked category: 0 | sampled posterior value = -1.8056428324730494
# best = -1.2838231207137771
# trial 4/5 | iteration 61/100
# picked category: 0 | sampled posterior value = -2.1494913896538947
# best = -1.2838231207137771
# trial 4/5 | iteration 62/100
# picked category: 0 | sampled posterior value = -2.0937016768833727
# best = -1.2838231207137771
# trial 4/5 | iteration 63/100
# picked category: 0 | sampled posterior value = -2.0451324875229155
# best = -1.2838231207137771
# trial 4/5 | iteration 64/100
# picked category: 0 | sampled posterior value = -2.1574326419125076
# best = -1.2838231207137771
# trial 4/5 | iteration 65/100
# picked category: 0 | sampled posterior value = -2.0318584834268343
# best = -1.2838231207137771
# trial 4/5 | iteration 66/100
# picked category: 0 | sampled posterior value = -2.3479202292055135
# best = -1.2838231207137771
# trial 4/5 | iteration 67/100
# picked category: 0 | sampled posterior value = -1.8413944277658065
# best = -1.2838231207137771
# trial 4/5 | iteration 68/100
# picked category: 0 | sampled posterior value = -2.0774953056513454
# best = -1.2838231207137771
# trial 4/5 | iteration 69/100
# picked category: 0 | sampled posterior value = -1.765285814938413
# best = -1.2838231207137771
# trial 4/5 | iteration 70/100
# picked category: 0 | sampled posterior value = -2.6021040880961155
# best = -1.2838231207137771
# trial 4/5 | iteration 71/100
# picked category: 0 | sampled posterior value = -2.381783991511068
# best = -1.2838231207137771
# trial 4/5 | iteration 72/100
# picked category: 0 | sampled posterior value = -2.042784700254349
# best = -1.2838231207137771
# trial 4/5 | iteration 73/100
# picked category: 0 | sampled posterior value = -1.7675320596241761
# best = -1.2838231207137771
# trial 4/5 | iteration 74/100
# picked category: 0 | sampled posterior value = -1.948657337648127
# best = -1.2838231207137771
# trial 4/5 | iteration 75/100
# picked category: 0 | sampled posterior value = -2.149135041351277
# best = -1.2838231207137771
# trial 4/5 | iteration 76/100
# picked category: 0 | sampled posterior value = -1.9707644116803187
# best = -1.2838231207137771
# trial 4/5 | iteration 77/100
# picked category: 0 | sampled posterior value = -1.8341645049768334
# best = -1.2838231207137771
# trial 4/5 | iteration 78/100
# picked category: 0 | sampled posterior value = -1.62414978832057
# best = -0.8961270924737303
# trial 4/5 | iteration 79/100
# picked category: 0 | sampled posterior value = -1.8441624842298754
# best = -0.8961270924737303
# trial 4/5 | iteration 80/100
# picked category: 0 | sampled posterior value = -1.6511711474766901
# best = -0.8961270924737303
# trial 4/5 | iteration 81/100
# picked category: 0 | sampled posterior value = -1.482348254604935
# best = -0.8961270924737303
# trial 4/5 | iteration 82/100
# picked category: 0 | sampled posterior value = -2.181642126310985
# best = -0.8961270924737303
# trial 4/5 | iteration 83/100
# picked category: 0 | sampled posterior value = -1.977191474334028
# best = -0.8961270924737303
# trial 4/5 | iteration 84/100
# picked category: 0 | sampled posterior value = -1.684838510529838
# best = -0.8961270924737303
# trial 4/5 | iteration 85/100
# picked category: 0 | sampled posterior value = -1.6086222232558312
# best = -0.8961270924737303
# trial 4/5 | iteration 86/100
# picked category: 0 | sampled posterior value = -2.6441871291550934
# best = -0.8961270924737303
# trial 4/5 | iteration 87/100
# picked category: 0 | sampled posterior value = -1.841088000836773
# best = -0.8961270924737303
# trial 4/5 | iteration 88/100
# picked category: 0 | sampled posterior value = -1.418206772639512
# best = -0.8961270924737303
# trial 4/5 | iteration 89/100
# picked category: 0 | sampled posterior value = -1.9067846504602832
# best = -0.8961270924737303
# trial 4/5 | iteration 90/100
# picked category: 0 | sampled posterior value = -1.7548207817123112
# best = -0.8961270924737303
# trial 4/5 | iteration 91/100
# picked category: 0 | sampled posterior value = -2.2617895980320886
# best = -0.8961270924737303
# trial 4/5 | iteration 92/100
# picked category: 0 | sampled posterior value = -1.9446657880883003
# best = -0.8961270924737303
# trial 4/5 | iteration 93/100
# picked category: 0 | sampled posterior value = -2.230591802537109
# best = -0.8961270924737303
# trial 4/5 | iteration 94/100
# picked category: 0 | sampled posterior value = -2.2822981326165084
# best = -0.8961270924737303
# trial 4/5 | iteration 95/100
# picked category: 0 | sampled posterior value = -2.100991420340201
# best = -0.8961270924737303
# trial 4/5 | iteration 96/100
# picked category: 0 | sampled posterior value = -2.472751763778751
# best = -0.8961270924737303
# trial 4/5 | iteration 97/100
# picked category: 0 | sampled posterior value = -2.2239427718511995
# best = -0.8961270924737303
# trial 4/5 | iteration 98/100
# picked category: 0 | sampled posterior value = -1.8173934353360792
# best = -0.8961270924737303
# trial 4/5 | iteration 99/100
# picked category: 0 | sampled posterior value = -2.2997162219653386
# best = -0.8961270924737303
# trial 4/5 | iteration 100/100
# picked category: 0 | sampled posterior value = -2.0941007368953564
# best = -0.8961270924737303
# trial 5/5 | iteration 1/100
# picked category: 0 | sampled posterior value = -3.814345361785469
# best = -4.244669515320577
# trial 5/5 | iteration 2/100
# picked category: 0 | sampled posterior value = -3.2756334475689153
# best = -4.244669515320577
# trial 5/5 | iteration 3/100
# picked category: 0 | sampled posterior value = -4.089490024118345
# best = -3.242504945575274
# trial 5/5 | iteration 4/100
# picked category: 0 | sampled posterior value = -2.9814573017770343
# best = -3.242504945575274
# trial 5/5 | iteration 5/100
# picked category: 0 | sampled posterior value = -3.3613810162599815
# best = -3.242504945575274
# trial 5/5 | iteration 6/100
# picked category: 0 | sampled posterior value = -3.225227284237839
# best = -3.242504945575274
# trial 5/5 | iteration 7/100
# picked category: 0 | sampled posterior value = -3.9515432160841675
# best = -3.242504945575274
# trial 5/5 | iteration 8/100
# picked category: 0 | sampled posterior value = -3.073651599255311
# best = -3.242504945575274
# trial 5/5 | iteration 9/100
# picked category: 0 | sampled posterior value = -3.7819609777468113
# best = -3.242504945575274
# trial 5/5 | iteration 10/100
# picked category: 0 | sampled posterior value = -3.2506232981942285
# best = -2.7962102881570243
# trial 5/5 | iteration 11/100
# picked category: 0 | sampled posterior value = -3.2036037129815247
# best = -2.7962102881570243
# trial 5/5 | iteration 12/100
# picked category: 0 | sampled posterior value = -3.202384356678109
# best = -2.7962102881570243
# trial 5/5 | iteration 13/100
# picked category: 0 | sampled posterior value = -2.950206493301133
# best = -2.7962102881570243
# trial 5/5 | iteration 14/100
# picked category: 0 | sampled posterior value = -3.273451932877287
# best = -2.7962102881570243
# trial 5/5 | iteration 15/100
# picked category: 0 | sampled posterior value = -3.5421624859403265
# best = -2.4972726864488775
# trial 5/5 | iteration 16/100
# picked category: 0 | sampled posterior value = -2.662884136337519
# best = -2.4972726864488775
# trial 5/5 | iteration 17/100
# picked category: 0 | sampled posterior value = -2.7400612944415483
# best = -2.4972726864488775
# trial 5/5 | iteration 18/100
# picked category: 0 | sampled posterior value = -3.077009109028234
# best = -2.4972726864488775
# trial 5/5 | iteration 19/100
# picked category: 0 | sampled posterior value = -3.0113542914313034
# best = -2.4972726864488775
# trial 5/5 | iteration 20/100
# picked category: 0 | sampled posterior value = -3.15909674916796
# best = -2.4972726864488775
# trial 5/5 | iteration 21/100
# picked category: 0 | sampled posterior value = -3.235197570640967
# best = -2.4972726864488775
# trial 5/5 | iteration 22/100
# picked category: 0 | sampled posterior value = -3.413878480488506
# best = -2.4972726864488775
# trial 5/5 | iteration 23/100
# picked category: 0 | sampled posterior value = -3.2635880981644148
# best = -2.4972726864488775
# trial 5/5 | iteration 24/100
# picked category: 0 | sampled posterior value = -3.254627496664922
# best = -2.4972726864488775
# trial 5/5 | iteration 25/100
# picked category: 0 | sampled posterior value = -3.191406770253997
# best = -2.4972726864488775
# trial 5/5 | iteration 26/100
# picked category: 0 | sampled posterior value = -3.298817844183796
# best = -2.4972726864488775
# trial 5/5 | iteration 27/100
# picked category: 0 | sampled posterior value = -3.0203367976627713
# best = -2.4972726864488775
# trial 5/5 | iteration 28/100
# picked category: 0 | sampled posterior value = -2.8784393760282003
# best = -2.4972726864488775
# trial 5/5 | iteration 29/100
# picked category: 0 | sampled posterior value = -2.7984146030739074
# best = -2.4972726864488775
# trial 5/5 | iteration 30/100
# picked category: 0 | sampled posterior value = -2.898131087586137
# best = -2.4972726864488775
# trial 5/5 | iteration 31/100
# picked category: 0 | sampled posterior value = -2.714839959240466
# best = -2.4972726864488775
# trial 5/5 | iteration 32/100
# picked category: 0 | sampled posterior value = -3.361719227969214
# best = -2.4972726864488775
# trial 5/5 | iteration 33/100
# picked category: 0 | sampled posterior value = -2.983698657887942
# best = -2.4972726864488775
# trial 5/5 | iteration 34/100
# picked category: 0 | sampled posterior value = -2.7154615844740855
# best = -2.4972726864488775
# trial 5/5 | iteration 35/100
# picked category: 0 | sampled posterior value = -2.9541413332340545
# best = -2.4972726864488775
# trial 5/5 | iteration 36/100
# picked category: 0 | sampled posterior value = -3.1918606268500875
# best = -2.4972726864488775
# trial 5/5 | iteration 37/100
# picked category: 0 | sampled posterior value = -2.954711635130873
# best = -2.4972726864488775
# trial 5/5 | iteration 38/100
# picked category: 0 | sampled posterior value = -2.875873395743754
# best = -2.4972726864488775
# trial 5/5 | iteration 39/100
# picked category: 0 | sampled posterior value = -3.081499608545098
# best = -2.4972726864488775
# trial 5/5 | iteration 40/100
# picked category: 0 | sampled posterior value = -3.035282421551333
# best = -1.915329906623779
# trial 5/5 | iteration 41/100
# picked category: 0 | sampled posterior value = -2.953673878715774
# best = -1.915329906623779
# trial 5/5 | iteration 42/100
# picked category: 0 | sampled posterior value = -2.8593063436268564
# best = -1.5278315488372631
# trial 5/5 | iteration 43/100
# picked category: 0 | sampled posterior value = -2.7179319834982034
# best = -1.5278315488372631
# trial 5/5 | iteration 44/100
# picked category: 0 | sampled posterior value = -2.7552008998102746
# best = -1.5278315488372631
# trial 5/5 | iteration 45/100
# picked category: 0 | sampled posterior value = -2.546387646465297
# best = -1.5278315488372631
# trial 5/5 | iteration 46/100
# picked category: 0 | sampled posterior value = -2.6677436797487832
# best = -1.5278315488372631
# trial 5/5 | iteration 47/100
# picked category: 0 | sampled posterior value = -2.6995860932677225
# best = -1.5278315488372631
# trial 5/5 | iteration 48/100
# picked category: 0 | sampled posterior value = -2.6231000661743082
# best = -1.5278315488372631
# trial 5/5 | iteration 49/100
# picked category: 0 | sampled posterior value = -2.644497822204224
# best = -1.5278315488372631
# trial 5/5 | iteration 50/100
# picked category: 0 | sampled posterior value = -2.927879175230156
# best = -1.5278315488372631
# trial 5/5 | iteration 51/100
# picked category: 0 | sampled posterior value = -2.696603823894041
# best = -1.5278315488372631
# trial 5/5 | iteration 52/100
# picked category: 0 | sampled posterior value = -2.5406202630465105
# best = -1.5278315488372631
# trial 5/5 | iteration 53/100
# picked category: 0 | sampled posterior value = -2.813581029199238
# best = -1.5278315488372631
# trial 5/5 | iteration 54/100
# picked category: 0 | sampled posterior value = -2.7782551670504625
# best = -1.5278315488372631
# trial 5/5 | iteration 55/100
# picked category: 0 | sampled posterior value = -2.535597583984107
# best = -1.5278315488372631
# trial 5/5 | iteration 56/100
# picked category: 0 | sampled posterior value = -2.7389098364648694
# best = -1.5278315488372631
# trial 5/5 | iteration 57/100
# picked category: 0 | sampled posterior value = -2.592141737908913
# best = -1.5278315488372631
# trial 5/5 | iteration 58/100
# picked category: 0 | sampled posterior value = -2.5609264738969832
# best = -1.5278315488372631
# trial 5/5 | iteration 59/100
# picked category: 0 | sampled posterior value = -2.612773171171126
# best = -1.5278315488372631
# trial 5/5 | iteration 60/100
# picked category: 0 | sampled posterior value = -2.525030616576603
# best = -1.5278315488372631
# trial 5/5 | iteration 61/100
# picked category: 0 | sampled posterior value = -2.4328391112500767
# best = -1.5278315488372631
# trial 5/5 | iteration 62/100
# picked category: 0 | sampled posterior value = -2.6504513445101012
# best = -1.5278315488372631
# trial 5/5 | iteration 63/100
# picked category: 0 | sampled posterior value = -2.181696727660672
# best = -1.14763941839939
# trial 5/5 | iteration 64/100
# picked category: 0 | sampled posterior value = -2.5876762000911078
# best = -1.14763941839939
# trial 5/5 | iteration 65/100
# picked category: 0 | sampled posterior value = -2.7199799525791466
# best = -1.14763941839939
# trial 5/5 | iteration 66/100
# picked category: 0 | sampled posterior value = -2.60205240494872
# best = -1.14763941839939
# trial 5/5 | iteration 67/100
# picked category: 0 | sampled posterior value = -2.405106538100924
# best = -1.14763941839939
# trial 5/5 | iteration 68/100
# picked category: 0 | sampled posterior value = -2.739559814289604
# best = -1.14763941839939
# trial 5/5 | iteration 69/100
# picked category: 0 | sampled posterior value = -2.3913371164594057
# best = -1.14763941839939
# trial 5/5 | iteration 70/100
# picked category: 0 | sampled posterior value = -2.6331277920081524
# best = -1.14763941839939
# trial 5/5 | iteration 71/100
# picked category: 0 | sampled posterior value = -2.5889177013400353
# best = -1.14763941839939
# trial 5/5 | iteration 72/100
# picked category: 0 | sampled posterior value = -2.3442014447782595
# best = -1.14763941839939
# trial 5/5 | iteration 73/100
# picked category: 0 | sampled posterior value = -2.077260057728627
# best = -1.14763941839939
# trial 5/5 | iteration 74/100
# picked category: 0 | sampled posterior value = -2.3498216172187565
# best = -1.14763941839939
# trial 5/5 | iteration 75/100
# picked category: 0 | sampled posterior value = -2.573999954101394
# best = -1.14763941839939
# trial 5/5 | iteration 76/100
# picked category: 0 | sampled posterior value = -2.4134226994812655
# best = -1.14763941839939
# trial 5/5 | iteration 77/100
# picked category: 0 | sampled posterior value = -2.310745990629815
# best = -1.14763941839939
# trial 5/5 | iteration 78/100
# picked category: 0 | sampled posterior value = -2.4311294241831884
# best = -1.14763941839939
# trial 5/5 | iteration 79/100
# picked category: 0 | sampled posterior value = -2.277243646802686
# best = -1.14763941839939
# trial 5/5 | iteration 80/100
# picked category: 0 | sampled posterior value = -2.0093956136650957
# best = -1.14763941839939
# trial 5/5 | iteration 81/100
# picked category: 0 | sampled posterior value = -1.8769336866208586
# best = -1.14763941839939
# trial 5/5 | iteration 82/100
# picked category: 0 | sampled posterior value = -1.9302536707266114
# best = -1.14763941839939
# trial 5/5 | iteration 83/100
# picked category: 0 | sampled posterior value = -2.4019963408944975
# best = -1.14763941839939
# trial 5/5 | iteration 84/100
# picked category: 0 | sampled posterior value = -2.1237438976812095
# best = -1.14763941839939
# trial 5/5 | iteration 85/100
# picked category: 0 | sampled posterior value = -1.8920289493923697
# best = -1.14763941839939
# trial 5/5 | iteration 86/100
# picked category: 0 | sampled posterior value = -2.1189893986139943
# best = -1.14763941839939
# trial 5/5 | iteration 87/100
# picked category: 0 | sampled posterior value = -2.0706124115991056
# best = -1.14763941839939
# trial 5/5 | iteration 88/100
# picked category: 0 | sampled posterior value = -2.1821798029444675
# best = -1.14763941839939
# trial 5/5 | iteration 89/100
# picked category: 0 | sampled posterior value = -1.8848733402977391
# best = -1.14763941839939
# trial 5/5 | iteration 90/100
# picked category: 0 | sampled posterior value = -2.151501137904041
# best = -1.14763941839939
# trial 5/5 | iteration 91/100
# picked category: 0 | sampled posterior value = -1.937692163180555
# best = -1.14763941839939
# trial 5/5 | iteration 92/100
# picked category: 0 | sampled posterior value = -2.1835547247155738
# best = -1.14763941839939
# trial 5/5 | iteration 93/100
# picked category: 0 | sampled posterior value = -1.766297369552434
# best = -1.14763941839939
# trial 5/5 | iteration 94/100
# picked category: 0 | sampled posterior value = -2.511876349194968
# best = -1.14763941839939
# trial 5/5 | iteration 95/100
# picked category: 0 | sampled posterior value = -2.0099794605874735
# best = -1.14763941839939
# trial 5/5 | iteration 96/100
# picked category: 0 | sampled posterior value = -1.879146769755071
# best = -1.1237753994821031
# trial 5/5 | iteration 97/100
# picked category: 0 | sampled posterior value = -2.040693210331121
# best = -1.1237753994821031
# trial 5/5 | iteration 98/100
# picked category: 0 | sampled posterior value = -2.3104964640552046
# best = -1.1237753994821031
# trial 5/5 | iteration 99/100
# picked category: 0 | sampled posterior value = -2.337232380876483
# best = -1.1237753994821031
# trial 5/5 | iteration 100/100
# picked category: 0 | sampled posterior value = -2.4462025123332554
# best = -1.1237753994821031

# %% [markdown]
# ### One-hot

# %%
# BO LOOP

best_values = torch.empty(N_TRIALS, N_ITERS + 1, **tkwargs)

for t in range(N_TRIALS):
    
    # generate starting dataset
    train_X = oh.generate_X(m, C, BOUNDS, seed=t).to(**tkwargs)
    train_y = oh.modified_neg_ackley(train_X, C).to(**tkwargs)
    best_values[t, 0] = train_y.max().item()

    
    for i in range(1, N_ITERS + 1):
        
        print(f"trial {t+1}/{N_TRIALS} | iteration {i}/{N_ITERS}")
        
        new_X = []
        
        for j in range(N_CANDIDATES):
            
            # set X_pending
            if len(new_X) > 0:
                X_pending = torch.cat(new_X, dim=0)
            else:
                X_pending = None
        
            # normalize X
            train_X_normalized = oh.normalize_with_bounds(train_X, C, BOUNDS)
        
            # initialize model
            model = oh.initialize_models(train_X_normalized, train_y, nu=NU)
            
            # define acqf
            acqf = qExpectedImprovement(model=model, 
                                        best_f=train_y.max(),
                                        sampler=qmc_sampler,
                                        X_pending=X_pending)
        
            # get candidates
            X_picked = oh.get_candidate(acqf, BOUNDS_ACQF, C)
            new_X.append(X_picked)
            
        new_X = torch.cat(new_X, dim=0).to(**tkwargs)
        
        # denormalize candidates
        new_X = oh.denormalize_with_bounds(new_X, C, BOUNDS)
        
        # evaluate objective
        new_y = oh.modified_neg_ackley(new_X, C).to(**tkwargs)
        
        # update train_X and train_y
        train_X = torch.cat([train_X, new_X], dim=0)
        train_y = torch.cat([train_y, new_y], dim=0)
        
        # update best values
        best = train_y.max().item()
        print(f"best = {best}")
        best_values[t, i] = best
# Out:
# trial 1/5 | iteration 1/100
# best = -5.6585262806589505
# trial 1/5 | iteration 2/100
# best = -5.6585262806589505
# trial 1/5 | iteration 3/100
# best = -3.2666213164203772
# trial 1/5 | iteration 4/100
# best = -3.2666213164203772
# trial 1/5 | iteration 5/100
# best = -3.2666213164203772
# trial 1/5 | iteration 6/100
# best = -2.6989146869669196
# trial 1/5 | iteration 7/100
# best = -2.6989146869669196
# trial 1/5 | iteration 8/100
# best = -2.6989146869669196
# trial 1/5 | iteration 9/100
# best = -2.6989146869669196
# trial 1/5 | iteration 10/100
# best = -2.6989146869669196
# trial 1/5 | iteration 11/100
# best = -2.6989146869669196
# trial 1/5 | iteration 12/100
# best = -2.6989146869669196
# trial 1/5 | iteration 13/100
# best = -2.6989146869669196
# trial 1/5 | iteration 14/100
# best = -2.6989146869669196
# trial 1/5 | iteration 15/100
# best = -2.6989146869669196
# trial 1/5 | iteration 16/100
# best = -2.6989146869669196
# trial 1/5 | iteration 17/100
# best = -2.6989146869669196
# trial 1/5 | iteration 18/100
# best = -2.6989146869669196
# trial 1/5 | iteration 19/100
# best = -2.6989146869669196
# trial 1/5 | iteration 20/100
# best = -2.6989146869669196
# trial 1/5 | iteration 21/100
# best = -2.6989146869669196
# trial 1/5 | iteration 22/100
# best = -2.6989146869669196
# trial 1/5 | iteration 23/100
# best = -2.6989146869669196
# trial 1/5 | iteration 24/100
# best = -2.6989146869669196
# trial 1/5 | iteration 25/100
# best = -2.6989146869669196
# trial 1/5 | iteration 26/100
# best = -2.6989146869669196
# trial 1/5 | iteration 27/100
# best = -2.6989146869669196
# trial 1/5 | iteration 28/100
# best = -2.6989146869669196
# trial 1/5 | iteration 29/100
# best = -2.6989146869669196
# trial 1/5 | iteration 30/100
# best = -2.3498074113449268
# trial 1/5 | iteration 31/100
# best = -2.3498074113449268
# trial 1/5 | iteration 32/100
# best = -2.3498074113449268
# trial 1/5 | iteration 33/100
# best = -2.3498074113449268
# trial 1/5 | iteration 34/100
# best = -2.3498074113449268
# trial 1/5 | iteration 35/100
# best = -2.3498074113449268
# trial 1/5 | iteration 36/100
# best = -2.3498074113449268
# trial 1/5 | iteration 37/100
# best = -2.3498074113449268
# trial 1/5 | iteration 38/100
# best = -2.3498074113449268
# trial 1/5 | iteration 39/100
# best = -2.3498074113449268
# trial 1/5 | iteration 40/100
# best = -2.3498074113449268
# trial 1/5 | iteration 41/100
# best = -2.3498074113449268
# trial 1/5 | iteration 42/100
# best = -2.3498074113449268
# trial 1/5 | iteration 43/100
# best = -2.3498074113449268
# trial 1/5 | iteration 44/100
# best = -2.3498074113449268
# trial 1/5 | iteration 45/100
# best = -2.3498074113449268
# trial 1/5 | iteration 46/100
# best = -2.3498074113449268
# trial 1/5 | iteration 47/100
# best = -2.3498074113449268
# trial 1/5 | iteration 48/100
# best = -2.3498074113449268
# trial 1/5 | iteration 49/100
# best = -2.3498074113449268
# trial 1/5 | iteration 50/100
# best = -2.3498074113449268
# trial 1/5 | iteration 51/100
# best = -2.3498074113449268
# trial 1/5 | iteration 52/100
# best = -2.3498074113449268
# trial 1/5 | iteration 53/100
# best = -2.3498074113449268
# trial 1/5 | iteration 54/100
# best = -2.3498074113449268
# trial 1/5 | iteration 55/100
# best = -2.3498074113449268
# trial 1/5 | iteration 56/100
# best = -2.3498074113449268
# trial 1/5 | iteration 57/100
# best = -2.3498074113449268
# trial 1/5 | iteration 58/100
# best = -2.3498074113449268
# trial 1/5 | iteration 59/100
# best = -2.3498074113449268
# trial 1/5 | iteration 60/100
# best = -2.3498074113449268
# trial 1/5 | iteration 61/100
# best = -2.3498074113449268
# trial 1/5 | iteration 62/100
# best = -2.3498074113449268
# trial 1/5 | iteration 63/100
# best = -2.3498074113449268
# trial 1/5 | iteration 64/100
# best = -2.3498074113449268
# trial 1/5 | iteration 65/100
# best = -2.3498074113449268
# trial 1/5 | iteration 66/100
# best = -2.3498074113449268
# trial 1/5 | iteration 67/100
# best = -2.3498074113449268
# trial 1/5 | iteration 68/100
# best = -2.3498074113449268
# trial 1/5 | iteration 69/100
# best = -2.3498074113449268
# trial 1/5 | iteration 70/100
# best = -2.3498074113449268
# trial 1/5 | iteration 71/100
# best = -2.3498074113449268
# trial 1/5 | iteration 72/100
# best = -2.3498074113449268
# trial 1/5 | iteration 73/100
# best = -2.3498074113449268
# trial 1/5 | iteration 74/100
# best = -2.3498074113449268
# trial 1/5 | iteration 75/100
# best = -2.3498074113449268
# trial 1/5 | iteration 76/100
# best = -2.3498074113449268
# trial 1/5 | iteration 77/100
# best = -2.3498074113449268
# trial 1/5 | iteration 78/100
# best = -2.3498074113449268
# trial 1/5 | iteration 79/100
# best = -2.3498074113449268
# trial 1/5 | iteration 80/100
# best = -2.3498074113449268
# trial 1/5 | iteration 81/100
# best = -2.3498074113449268
# trial 1/5 | iteration 82/100
# best = -2.3498074113449268
# trial 1/5 | iteration 83/100
# best = -2.3498074113449268
# trial 1/5 | iteration 84/100
# best = -2.3498074113449268
# trial 1/5 | iteration 85/100
# best = -2.3498074113449268
# trial 1/5 | iteration 86/100
# best = -2.3498074113449268
# trial 1/5 | iteration 87/100
# best = -2.3498074113449268
# trial 1/5 | iteration 88/100
# best = -2.3498074113449268
# trial 1/5 | iteration 89/100
# best = -2.3498074113449268
# trial 1/5 | iteration 90/100
# best = -2.3498074113449268
# trial 1/5 | iteration 91/100
# best = -2.3498074113449268
# trial 1/5 | iteration 92/100
# best = -2.3498074113449268
# trial 1/5 | iteration 93/100
# best = -2.3498074113449268
# trial 1/5 | iteration 94/100
# best = -2.3498074113449268
# trial 1/5 | iteration 95/100
# best = -2.3498074113449268
# trial 1/5 | iteration 96/100
# best = -2.3498074113449268
# trial 1/5 | iteration 97/100
# best = -2.3498074113449268
# trial 1/5 | iteration 98/100
# best = -2.3498074113449268
# trial 1/5 | iteration 99/100
# best = -2.3498074113449268
# trial 1/5 | iteration 100/100
# best = -2.3498074113449268
# trial 2/5 | iteration 1/100
# best = -3.3938920453452757
# trial 2/5 | iteration 2/100
# best = -3.3938920453452757
# trial 2/5 | iteration 3/100
# best = -3.3938920453452757
# trial 2/5 | iteration 4/100
# best = -3.3938920453452757
# trial 2/5 | iteration 5/100
# best = -3.3938920453452757
# trial 2/5 | iteration 6/100
# best = -3.0420480285824216
# trial 2/5 | iteration 7/100
# best = -3.0420480285824216
# trial 2/5 | iteration 8/100
# best = -3.0420480285824216
# trial 2/5 | iteration 9/100
# best = -3.0420480285824216
# trial 2/5 | iteration 10/100
# best = -3.0420480285824216
# trial 2/5 | iteration 11/100
# best = -3.0420480285824216
# trial 2/5 | iteration 12/100
# best = -3.0420480285824216
# trial 2/5 | iteration 13/100
# best = -3.0420480285824216
# trial 2/5 | iteration 14/100
# best = -3.0420480285824216
# trial 2/5 | iteration 15/100
# best = -3.0420480285824216
# trial 2/5 | iteration 16/100
# best = -3.0420480285824216
# trial 2/5 | iteration 17/100
# best = -3.0420480285824216
# trial 2/5 | iteration 18/100
# best = -3.0420480285824216
# trial 2/5 | iteration 19/100
# best = -3.0420480285824216
# trial 2/5 | iteration 20/100
# best = -3.0420480285824216
# trial 2/5 | iteration 21/100
# best = -3.0420480285824216
# trial 2/5 | iteration 22/100
# best = -3.0420480285824216
# trial 2/5 | iteration 23/100
# best = -3.0420480285824216
# trial 2/5 | iteration 24/100
# best = -2.484548468944507
# trial 2/5 | iteration 25/100
# best = -2.484548468944507
# trial 2/5 | iteration 26/100
# best = -2.484548468944507
# trial 2/5 | iteration 27/100
# best = -2.484548468944507
# trial 2/5 | iteration 28/100
# best = -2.484548468944507
# trial 2/5 | iteration 29/100
# best = -2.484548468944507
# trial 2/5 | iteration 30/100
# best = -2.484548468944507
# trial 2/5 | iteration 31/100
# best = -2.484548468944507
# trial 2/5 | iteration 32/100
# best = -2.484548468944507
# trial 2/5 | iteration 33/100
# best = -2.484548468944507
# trial 2/5 | iteration 34/100
# best = -2.484548468944507
# trial 2/5 | iteration 35/100
# best = -2.484548468944507
# trial 2/5 | iteration 36/100
# best = -2.484548468944507
# trial 2/5 | iteration 37/100
# best = -2.484548468944507
# trial 2/5 | iteration 38/100
# best = -2.484548468944507
# trial 2/5 | iteration 39/100
# best = -2.484548468944507
# trial 2/5 | iteration 40/100
# best = -2.484548468944507
# trial 2/5 | iteration 41/100
# best = -2.484548468944507
# trial 2/5 | iteration 42/100
# best = -2.484548468944507
# trial 2/5 | iteration 43/100
# best = -2.484548468944507
# trial 2/5 | iteration 44/100
# best = -2.484548468944507
# trial 2/5 | iteration 45/100
# best = -2.484548468944507
# trial 2/5 | iteration 46/100
# best = -2.484548468944507
# trial 2/5 | iteration 47/100
# best = -2.484548468944507
# trial 2/5 | iteration 48/100
# best = -2.484548468944507
# trial 2/5 | iteration 49/100
# best = -2.484548468944507
# trial 2/5 | iteration 50/100
# best = -2.484548468944507
# trial 2/5 | iteration 51/100
# best = -2.484548468944507
# trial 2/5 | iteration 52/100
# best = -2.484548468944507
# trial 2/5 | iteration 53/100
# best = -2.484548468944507
# trial 2/5 | iteration 54/100
# best = -2.484548468944507
# trial 2/5 | iteration 55/100
# best = -2.484548468944507
# trial 2/5 | iteration 56/100
# best = -2.484548468944507
# trial 2/5 | iteration 57/100
# best = -2.484548468944507
# trial 2/5 | iteration 58/100
# best = -2.484548468944507
# trial 2/5 | iteration 59/100
# best = -2.484548468944507
# trial 2/5 | iteration 60/100
# best = -2.484548468944507
# trial 2/5 | iteration 61/100
# best = -2.484548468944507
# trial 2/5 | iteration 62/100
# best = -2.484548468944507
# trial 2/5 | iteration 63/100
# best = -2.484548468944507
# trial 2/5 | iteration 64/100
# best = -2.484548468944507
# trial 2/5 | iteration 65/100
# best = -2.484548468944507
# trial 2/5 | iteration 66/100
# best = -2.484548468944507
# trial 2/5 | iteration 67/100
# best = -2.484548468944507
# trial 2/5 | iteration 68/100
# best = -2.484548468944507
# trial 2/5 | iteration 69/100
# best = -2.484548468944507
# trial 2/5 | iteration 70/100
# best = -2.484548468944507
# trial 2/5 | iteration 71/100
# best = -2.484548468944507
# trial 2/5 | iteration 72/100
# best = -2.484548468944507
# trial 2/5 | iteration 73/100
# best = -2.484548468944507
# trial 2/5 | iteration 74/100
# best = -2.484548468944507
# trial 2/5 | iteration 75/100
# best = -2.484548468944507
# trial 2/5 | iteration 76/100
# best = -2.484548468944507
# trial 2/5 | iteration 77/100
# best = -2.484548468944507
# trial 2/5 | iteration 78/100
# best = -2.484548468944507
# trial 2/5 | iteration 79/100
# best = -2.484548468944507
# trial 2/5 | iteration 80/100
# best = -2.484548468944507
# trial 2/5 | iteration 81/100
# best = -2.484548468944507
# trial 2/5 | iteration 82/100
# best = -2.484548468944507
# trial 2/5 | iteration 83/100
# best = -2.484548468944507
# trial 2/5 | iteration 84/100
# best = -2.484548468944507
# trial 2/5 | iteration 85/100
# best = -2.484548468944507
# trial 2/5 | iteration 86/100
# best = -2.484548468944507
# trial 2/5 | iteration 87/100
# best = -2.484548468944507
# trial 2/5 | iteration 88/100
# best = -2.484548468944507
# trial 2/5 | iteration 89/100
# best = -2.484548468944507
# trial 2/5 | iteration 90/100
# best = -2.484548468944507
# trial 2/5 | iteration 91/100
# best = -2.484548468944507
# trial 2/5 | iteration 92/100
# best = -2.484548468944507
# trial 2/5 | iteration 93/100
# best = -2.484548468944507
# trial 2/5 | iteration 94/100
# best = -2.484548468944507
# trial 2/5 | iteration 95/100
# best = -2.484548468944507
# trial 2/5 | iteration 96/100
# best = -2.484548468944507
# trial 2/5 | iteration 97/100
# best = -2.484548468944507
# trial 2/5 | iteration 98/100
# best = -2.484548468944507
# trial 2/5 | iteration 99/100
# best = -2.484548468944507
# trial 2/5 | iteration 100/100
# best = -2.484548468944507
# trial 3/5 | iteration 1/100
# best = -3.686686645167779
# trial 3/5 | iteration 2/100
# best = -3.414092641680899
# trial 3/5 | iteration 3/100
# best = -3.414092641680899
# trial 3/5 | iteration 4/100
# best = -3.414092641680899
# trial 3/5 | iteration 5/100
# best = -2.8382383777802116
# trial 3/5 | iteration 6/100
# best = -2.8382383777802116
# trial 3/5 | iteration 7/100
# best = -2.3441073679112567
# trial 3/5 | iteration 8/100
# best = -2.3441073679112567
# trial 3/5 | iteration 9/100
# best = -2.3441073679112567
# trial 3/5 | iteration 10/100
# best = -2.3441073679112567
# trial 3/5 | iteration 11/100
# best = -2.3441073679112567
# trial 3/5 | iteration 12/100
# best = -2.3441073679112567
# trial 3/5 | iteration 13/100
# best = -2.3441073679112567
# trial 3/5 | iteration 14/100
# best = -2.3441073679112567
# trial 3/5 | iteration 15/100
# best = -2.3441073679112567
# trial 3/5 | iteration 16/100
# best = -2.3441073679112567
# trial 3/5 | iteration 17/100
# best = -2.3441073679112567
# trial 3/5 | iteration 18/100
# best = -2.3441073679112567
# trial 3/5 | iteration 19/100
# best = -2.3441073679112567
# trial 3/5 | iteration 20/100
# best = -2.3441073679112567
# trial 3/5 | iteration 21/100
# best = -2.3441073679112567
# trial 3/5 | iteration 22/100
# best = -2.3441073679112567
# trial 3/5 | iteration 23/100
# best = -2.3441073679112567
# trial 3/5 | iteration 24/100
# best = -2.3441073679112567
# trial 3/5 | iteration 25/100
# best = -2.3441073679112567
# trial 3/5 | iteration 26/100
# best = -2.3441073679112567
# trial 3/5 | iteration 27/100
# best = -2.3441073679112567
# trial 3/5 | iteration 28/100
# best = -2.3441073679112567
# trial 3/5 | iteration 29/100
# best = -2.3441073679112567
# trial 3/5 | iteration 30/100
# best = -2.3441073679112567
# trial 3/5 | iteration 31/100
# best = -2.3441073679112567
# trial 3/5 | iteration 32/100
# best = -2.3441073679112567
# trial 3/5 | iteration 33/100
# best = -2.3441073679112567
# trial 3/5 | iteration 34/100
# best = -2.3441073679112567
# trial 3/5 | iteration 35/100
# best = -2.3441073679112567
# trial 3/5 | iteration 36/100
# best = -2.3441073679112567
# trial 3/5 | iteration 37/100
# best = -2.3441073679112567
# trial 3/5 | iteration 38/100
# best = -2.3441073679112567
# trial 3/5 | iteration 39/100
# best = -2.3441073679112567
# trial 3/5 | iteration 40/100
# best = -2.3441073679112567
# trial 3/5 | iteration 41/100
# best = -2.3441073679112567
# trial 3/5 | iteration 42/100
# best = -2.3441073679112567
# trial 3/5 | iteration 43/100
# best = -2.3441073679112567
# trial 3/5 | iteration 44/100
# best = -2.3441073679112567
# trial 3/5 | iteration 45/100
# best = -2.3441073679112567
# trial 3/5 | iteration 46/100
# best = -2.3441073679112567
# trial 3/5 | iteration 47/100
# best = -2.3441073679112567
# trial 3/5 | iteration 48/100
# best = -2.3441073679112567
# trial 3/5 | iteration 49/100
# best = -2.3441073679112567
# trial 3/5 | iteration 50/100
# best = -2.3441073679112567
# trial 3/5 | iteration 51/100
# best = -2.3441073679112567
# trial 3/5 | iteration 52/100
# best = -2.3441073679112567
# trial 3/5 | iteration 53/100
# best = -2.3441073679112567
# trial 3/5 | iteration 54/100
# best = -2.3441073679112567
# trial 3/5 | iteration 55/100
# best = -2.3441073679112567
# trial 3/5 | iteration 56/100
# best = -2.3441073679112567
# trial 3/5 | iteration 57/100
# best = -2.3441073679112567
# trial 3/5 | iteration 58/100
# best = -2.3441073679112567
# trial 3/5 | iteration 59/100
# best = -2.3441073679112567
# trial 3/5 | iteration 60/100
# best = -2.3441073679112567
# trial 3/5 | iteration 61/100
# best = -2.3441073679112567
# trial 3/5 | iteration 62/100
# best = -2.3441073679112567
# trial 3/5 | iteration 63/100
# best = -2.3441073679112567
# trial 3/5 | iteration 64/100
# best = -2.3441073679112567
# trial 3/5 | iteration 65/100
# best = -2.3441073679112567
# trial 3/5 | iteration 66/100
# best = -2.3441073679112567
# trial 3/5 | iteration 67/100
# best = -2.3441073679112567
# trial 3/5 | iteration 68/100
# best = -2.3441073679112567
# trial 3/5 | iteration 69/100
# best = -2.3441073679112567
# trial 3/5 | iteration 70/100
# best = -2.3441073679112567
# trial 3/5 | iteration 71/100
# best = -2.3441073679112567
# trial 3/5 | iteration 72/100
# best = -2.3441073679112567
# trial 3/5 | iteration 73/100
# best = -2.3441073679112567
# trial 3/5 | iteration 74/100
# best = -2.3441073679112567
# trial 3/5 | iteration 75/100
# best = -2.3441073679112567
# trial 3/5 | iteration 76/100
# best = -2.3441073679112567
# trial 3/5 | iteration 77/100
# best = -2.3441073679112567
# trial 3/5 | iteration 78/100
# best = -2.3441073679112567
# trial 3/5 | iteration 79/100
# best = -2.3441073679112567
# trial 3/5 | iteration 80/100
# best = -2.3441073679112567
# trial 3/5 | iteration 81/100
# best = -2.3441073679112567
# trial 3/5 | iteration 82/100
# best = -2.3441073679112567
# trial 3/5 | iteration 83/100
# best = -2.3441073679112567
# trial 3/5 | iteration 84/100
# best = -2.3441073679112567
# trial 3/5 | iteration 85/100
# best = -2.3441073679112567
# trial 3/5 | iteration 86/100
# best = -2.3441073679112567
# trial 3/5 | iteration 87/100
# best = -2.3441073679112567
# trial 3/5 | iteration 88/100
# best = -2.3441073679112567
# trial 3/5 | iteration 89/100
# best = -2.3441073679112567
# trial 3/5 | iteration 90/100
# best = -2.3441073679112567
# trial 3/5 | iteration 91/100
# best = -2.3441073679112567
# trial 3/5 | iteration 92/100
# best = -2.3441073679112567
# trial 3/5 | iteration 93/100
# best = -2.3441073679112567
# trial 3/5 | iteration 94/100
# best = -2.3441073679112567
# trial 3/5 | iteration 95/100
# best = -2.3441073679112567
# trial 3/5 | iteration 96/100
# best = -2.3441073679112567
# trial 3/5 | iteration 97/100
# best = -2.3441073679112567
# trial 3/5 | iteration 98/100
# best = -2.3441073679112567
# trial 3/5 | iteration 99/100
# best = -2.3441073679112567
# trial 3/5 | iteration 100/100
# best = -2.3441073679112567
# trial 4/5 | iteration 1/100
# best = -4.116492185025404
# trial 4/5 | iteration 2/100
# best = -3.493263200334202
# trial 4/5 | iteration 3/100
# best = -3.4615286704581973
# trial 4/5 | iteration 4/100
# best = -3.4615286704581973
# trial 4/5 | iteration 5/100
# best = -3.4615286704581973
# trial 4/5 | iteration 6/100
# best = -3.4615286704581973
# trial 4/5 | iteration 7/100
# best = -3.2135934622788125
# trial 4/5 | iteration 8/100
# best = -3.2135934622788125
# trial 4/5 | iteration 9/100
# best = -3.2135934622788125
# trial 4/5 | iteration 10/100
# best = -3.2135934622788125
# trial 4/5 | iteration 11/100
# best = -3.2135934622788125
# trial 4/5 | iteration 12/100
# best = -3.2135934622788125
# trial 4/5 | iteration 13/100
# best = -3.2135934622788125
# trial 4/5 | iteration 14/100
# best = -3.2135934622788125
# trial 4/5 | iteration 15/100
# best = -3.2135934622788125
# trial 4/5 | iteration 16/100
# best = -3.2135934622788125
# trial 4/5 | iteration 17/100
# best = -3.2135934622788125
# trial 4/5 | iteration 18/100
# best = -3.2135934622788125
# trial 4/5 | iteration 19/100
# best = -3.2135934622788125
# trial 4/5 | iteration 20/100
# best = -3.2135934622788125
# trial 4/5 | iteration 21/100
# best = -3.2135934622788125
# trial 4/5 | iteration 22/100
# best = -3.2135934622788125
# trial 4/5 | iteration 23/100
# best = -3.2135934622788125
# trial 4/5 | iteration 24/100
# best = -3.2135934622788125
# trial 4/5 | iteration 25/100
# best = -3.2135934622788125
# trial 4/5 | iteration 26/100
# best = -3.2135934622788125
# trial 4/5 | iteration 27/100
# best = -3.2135934622788125
# trial 4/5 | iteration 28/100
# best = -3.2135934622788125
# trial 4/5 | iteration 29/100
# best = -3.2135934622788125
# trial 4/5 | iteration 30/100
# best = -3.2135934622788125
# trial 4/5 | iteration 31/100
# best = -3.2135934622788125
# trial 4/5 | iteration 32/100
# best = -3.2135934622788125
# trial 4/5 | iteration 33/100
# best = -3.2135934622788125
# trial 4/5 | iteration 34/100
# best = -3.2135934622788125
# trial 4/5 | iteration 35/100
# best = -3.2135934622788125
# trial 4/5 | iteration 36/100
# best = -3.2135934622788125
# trial 4/5 | iteration 37/100
# best = -2.729029632826475
# trial 4/5 | iteration 38/100
# best = -2.729029632826475
# trial 4/5 | iteration 39/100
# best = -2.729029632826475
# trial 4/5 | iteration 40/100
# best = -2.729029632826475
# trial 4/5 | iteration 41/100
# best = -2.729029632826475
# trial 4/5 | iteration 42/100
# best = -2.729029632826475
# trial 4/5 | iteration 43/100
# best = -2.729029632826475
# trial 4/5 | iteration 44/100
# best = -2.729029632826475
# trial 4/5 | iteration 45/100
# best = -2.729029632826475
# trial 4/5 | iteration 46/100
# best = -2.729029632826475
# trial 4/5 | iteration 47/100
# best = -2.729029632826475
# trial 4/5 | iteration 48/100
# best = -2.729029632826475
# trial 4/5 | iteration 49/100
# best = -2.729029632826475
# trial 4/5 | iteration 50/100
# best = -2.729029632826475
# trial 4/5 | iteration 51/100
# best = -2.729029632826475
# trial 4/5 | iteration 52/100
# best = -2.729029632826475
# trial 4/5 | iteration 53/100
# best = -2.729029632826475
# trial 4/5 | iteration 54/100
# best = -2.729029632826475
# trial 4/5 | iteration 55/100
# best = -2.729029632826475
# trial 4/5 | iteration 56/100
# best = -2.729029632826475
# trial 4/5 | iteration 57/100
# best = -2.729029632826475
# trial 4/5 | iteration 58/100
# best = -2.729029632826475
# trial 4/5 | iteration 59/100
# best = -2.729029632826475
# trial 4/5 | iteration 60/100
# best = -2.729029632826475
# trial 4/5 | iteration 61/100
# best = -2.729029632826475
# trial 4/5 | iteration 62/100
# best = -2.729029632826475
# trial 4/5 | iteration 63/100
# best = -2.729029632826475
# trial 4/5 | iteration 64/100
# best = -2.729029632826475
# trial 4/5 | iteration 65/100
# best = -2.729029632826475
# trial 4/5 | iteration 66/100
# best = -2.729029632826475
# trial 4/5 | iteration 67/100
# best = -2.729029632826475
# trial 4/5 | iteration 68/100
# best = -2.729029632826475
# trial 4/5 | iteration 69/100
# best = -2.729029632826475
# trial 4/5 | iteration 70/100
# best = -2.729029632826475
# trial 4/5 | iteration 71/100
# best = -2.729029632826475
# trial 4/5 | iteration 72/100
# best = -2.729029632826475
# trial 4/5 | iteration 73/100
# best = -2.729029632826475
# trial 4/5 | iteration 74/100
# best = -2.729029632826475
# trial 4/5 | iteration 75/100
# best = -2.729029632826475
# trial 4/5 | iteration 76/100
# best = -2.729029632826475
# trial 4/5 | iteration 77/100
# best = -2.729029632826475
# trial 4/5 | iteration 78/100
# best = -2.729029632826475
# trial 4/5 | iteration 79/100
# best = -2.729029632826475
# trial 4/5 | iteration 80/100
# best = -2.729029632826475
# trial 4/5 | iteration 81/100
# best = -2.729029632826475
# trial 4/5 | iteration 82/100
# best = -2.729029632826475
# trial 4/5 | iteration 83/100
# best = -2.729029632826475
# trial 4/5 | iteration 84/100
# best = -2.729029632826475
# trial 4/5 | iteration 85/100
# best = -2.729029632826475
# trial 4/5 | iteration 86/100
# best = -2.729029632826475
# trial 4/5 | iteration 87/100
# best = -2.729029632826475
# trial 4/5 | iteration 88/100
# best = -2.729029632826475
# trial 4/5 | iteration 89/100
# best = -2.729029632826475
# trial 4/5 | iteration 90/100
# best = -2.729029632826475
# trial 4/5 | iteration 91/100
# best = -2.729029632826475
# trial 4/5 | iteration 92/100
# best = -2.729029632826475
# trial 4/5 | iteration 93/100
# best = -2.729029632826475
# trial 4/5 | iteration 94/100
# best = -2.729029632826475
# trial 4/5 | iteration 95/100
# best = -2.729029632826475
# trial 4/5 | iteration 96/100
# best = -2.729029632826475
# trial 4/5 | iteration 97/100
# best = -2.729029632826475
# trial 4/5 | iteration 98/100
# best = -2.729029632826475
# trial 4/5 | iteration 99/100
# best = -2.729029632826475
# trial 4/5 | iteration 100/100
# best = -2.729029632826475
# trial 5/5 | iteration 1/100
# best = -4.175756684568782
# trial 5/5 | iteration 2/100
# best = -4.175756684568782
# trial 5/5 | iteration 3/100
# best = -3.98220382756686
# trial 5/5 | iteration 4/100
# best = -3.7270655907097283
# trial 5/5 | iteration 5/100
# best = -3.7270655907097283
# trial 5/5 | iteration 6/100
# best = -2.831607809947237
# trial 5/5 | iteration 7/100
# best = -2.831607809947237
# trial 5/5 | iteration 8/100
# best = -2.831607809947237
# trial 5/5 | iteration 9/100
# best = -2.831607809947237
# trial 5/5 | iteration 10/100
# best = -2.831607809947237
# trial 5/5 | iteration 11/100
# best = -2.831607809947237
# trial 5/5 | iteration 12/100
# best = -2.831607809947237
# trial 5/5 | iteration 13/100
# best = -2.831607809947237
# trial 5/5 | iteration 14/100
# best = -2.831607809947237
# trial 5/5 | iteration 15/100
# best = -2.831607809947237
# trial 5/5 | iteration 16/100
# best = -2.831607809947237
# trial 5/5 | iteration 17/100
# best = -2.831607809947237
# trial 5/5 | iteration 18/100
# best = -2.831607809947237
# trial 5/5 | iteration 19/100
# best = -2.831607809947237
# trial 5/5 | iteration 20/100
# best = -2.831607809947237
# trial 5/5 | iteration 21/100
# best = -2.831607809947237
# trial 5/5 | iteration 22/100
# best = -2.831607809947237
# trial 5/5 | iteration 23/100
# best = -2.831607809947237
# trial 5/5 | iteration 24/100
# best = -2.831607809947237
# trial 5/5 | iteration 25/100
# best = -2.831607809947237
# trial 5/5 | iteration 26/100
# best = -2.831607809947237
# trial 5/5 | iteration 27/100
# best = -2.831607809947237
# trial 5/5 | iteration 28/100
# best = -2.831607809947237
# trial 5/5 | iteration 29/100
# best = -2.831607809947237
# trial 5/5 | iteration 30/100
# best = -2.831607809947237
# trial 5/5 | iteration 31/100
# best = -2.831607809947237
# trial 5/5 | iteration 32/100
# best = -2.831607809947237
# trial 5/5 | iteration 33/100
# best = -2.831607809947237
# trial 5/5 | iteration 34/100
# best = -2.831607809947237
# trial 5/5 | iteration 35/100
# best = -2.831607809947237
# trial 5/5 | iteration 36/100
# best = -2.831607809947237
# trial 5/5 | iteration 37/100
# best = -2.831607809947237
# trial 5/5 | iteration 38/100
# best = -2.831607809947237
# trial 5/5 | iteration 39/100
# best = -2.831607809947237
# trial 5/5 | iteration 40/100
# best = -2.831607809947237
# trial 5/5 | iteration 41/100
# best = -2.831607809947237
# trial 5/5 | iteration 42/100
# best = -2.831607809947237
# trial 5/5 | iteration 43/100
# best = -2.831607809947237
# trial 5/5 | iteration 44/100
# best = -2.831607809947237
# trial 5/5 | iteration 45/100
# best = -2.831607809947237
# trial 5/5 | iteration 46/100
# best = -2.831607809947237
# trial 5/5 | iteration 47/100
# best = -2.831607809947237
# trial 5/5 | iteration 48/100
# best = -2.831607809947237
# trial 5/5 | iteration 49/100
# best = -2.831607809947237
# trial 5/5 | iteration 50/100
# best = -2.831607809947237
# trial 5/5 | iteration 51/100
# best = -2.831607809947237
# trial 5/5 | iteration 52/100
# best = -2.831607809947237
# trial 5/5 | iteration 53/100
# best = -2.831607809947237
# trial 5/5 | iteration 54/100
# best = -2.831607809947237
# trial 5/5 | iteration 55/100
# best = -2.831607809947237
# trial 5/5 | iteration 56/100
# best = -2.831607809947237
# trial 5/5 | iteration 57/100
# best = -2.831607809947237
# trial 5/5 | iteration 58/100
# best = -2.831607809947237
# trial 5/5 | iteration 59/100
# best = -2.831607809947237
# trial 5/5 | iteration 60/100
# best = -2.831607809947237
# trial 5/5 | iteration 61/100
# best = -2.831607809947237
# trial 5/5 | iteration 62/100
# best = -2.831607809947237
# trial 5/5 | iteration 63/100
# best = -2.831607809947237
# trial 5/5 | iteration 64/100
# best = -2.831607809947237
# trial 5/5 | iteration 65/100
# best = -2.831607809947237
# trial 5/5 | iteration 66/100
# best = -2.831607809947237
# trial 5/5 | iteration 67/100
# best = -2.831607809947237
# trial 5/5 | iteration 68/100
# best = -2.831607809947237
# trial 5/5 | iteration 69/100
# best = -2.831607809947237
# trial 5/5 | iteration 70/100
# best = -2.831607809947237
# trial 5/5 | iteration 71/100
# best = -2.831607809947237
# trial 5/5 | iteration 72/100
# best = -2.831607809947237
# trial 5/5 | iteration 73/100
# best = -2.831607809947237
# trial 5/5 | iteration 74/100
# best = -2.831607809947237
# trial 5/5 | iteration 75/100
# best = -2.831607809947237
# trial 5/5 | iteration 76/100
# best = -2.831607809947237
# trial 5/5 | iteration 77/100
# best = -2.831607809947237
# trial 5/5 | iteration 78/100
# best = -2.831607809947237
# trial 5/5 | iteration 79/100
# best = -2.831607809947237
# trial 5/5 | iteration 80/100
# best = -2.831607809947237
# trial 5/5 | iteration 81/100
# best = -2.831607809947237
# trial 5/5 | iteration 82/100
# best = -2.831607809947237
# trial 5/5 | iteration 83/100
# best = -2.831607809947237
# trial 5/5 | iteration 84/100
# best = -2.831607809947237
# trial 5/5 | iteration 85/100
# best = -2.831607809947237
# trial 5/5 | iteration 86/100
# best = -2.831607809947237
# trial 5/5 | iteration 87/100
# best = -2.831607809947237
# trial 5/5 | iteration 88/100
# best = -2.831607809947237
# trial 5/5 | iteration 89/100
# best = -2.831607809947237
# trial 5/5 | iteration 90/100
# best = -2.831607809947237
# trial 5/5 | iteration 91/100
# best = -2.831607809947237
# trial 5/5 | iteration 92/100
# best = -2.831607809947237
# trial 5/5 | iteration 93/100
# best = -2.831607809947237
# trial 5/5 | iteration 94/100
# best = -2.831607809947237
# trial 5/5 | iteration 95/100
# best = -2.831607809947237
# trial 5/5 | iteration 96/100
# best = -2.831607809947237
# trial 5/5 | iteration 97/100
# best = -2.831607809947237
# trial 5/5 | iteration 98/100
# best = -2.831607809947237
# trial 5/5 | iteration 99/100
# best = -2.831607809947237
# trial 5/5 | iteration 100/100
# best = -2.831607809947237

# %%
# plot results

def ci(y):
    return 1.96 * y.std(axis=0) / np.sqrt(N_TRIALS)


GLOBAL_MAXIMUM = 0.0


obs = np.arange(N_ITERS + 1) * N_CANDIDATES
y1 = np.asarray(best_values.to('cpu'))
y2 = np.asarray(best_values_2.to('cpu'))

fig, ax = plt.subplots(1, 1, figsize=(8, 6))
ax.errorbar(obs, y1.mean(axis=0), yerr=ci(y1), label="one-hot + EI", linewidth=1.5)
ax.errorbar(obs, y2.mean(axis=0), yerr=ci(y2), label="MAB", linewidth=1.5)
plt.plot([0, N_ITERS * N_CANDIDATES], [GLOBAL_MAXIMUM] * 2, 'k', label="true best objective", linewidth=2)
ax.set_ylim(bottom=-5, top=1)
ax.set(xlabel='number of observations (beyond initial points)', ylabel='best objective value')
ax.legend(loc="lower right")
