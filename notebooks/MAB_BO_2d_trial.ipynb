# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"\\scripts")

# %%
import numpy as np
import torch
from torch.quasirandom import SobolEngine
tkwargs = {"dtype": torch.double,
           "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
#            "device": torch.device("cpu")
          }
from botorch.models.transforms.outcome import Standardize
import matplotlib.pyplot as plt
from MAB_BO_utils import *
# Out:
# [pyKeOps]: Warning, no cuda detected. Switching to cpu only.

# %%
# global parameters


d = 2
m = 2*(d+1)
C = 3
BOUNDS = torch.tensor([[-1.0]*(d), [3.0]*(d)])


N_CANDIDATES = 1
SAMPLER = 'cholesky'
N_SAMPLES = 1000
NU = 0.5

N_TRIALS = 3
N_ITERS = 40

# %%
# BO LOOP

best_values = torch.empty(N_TRIALS, N_ITERS, **tkwargs)

for t in range(N_TRIALS):
    
    # generate starting dataset
    train_X = generate_X(m, d, C, BOUNDS, seed=t)
    train_y = modified_neg_ackley(train_X)

    
    for i in range(N_ITERS):
        
        print(f"trial {t+1}/{N_TRIALS} | iteration {i+1}/{N_ITERS} | ", end='')
    
        # normalize X 
        train_X_normalized = normalize_with_bounds(train_X, BOUNDS)
        # standardize y
        standardizer = Standardize(1)
        train_y_standardized = standardizer(train_y)[0]

        # initialize model
        models = initialize_models(train_X_normalized, train_y, nu=NU, sampler=SAMPLER)
        
        # get candidates
        new_X = get_candidates(models, d, N_CANDIDATES, N_SAMPLES, sampler=SAMPLER)
        
        # denormalize candidates
        new_X = denormalize_with_bounds(new_X, BOUNDS)
        
        # evaluate objective
        new_y = modified_neg_ackley(new_X)
        
        # update train_X and train_y
        train_X = torch.cat([train_X, new_X], dim=0)
        train_y = torch.cat([train_y, new_y], dim=0)
        
        # update best values
        best = train_y.max().item()
        print(f"best = {best}")
        best_values[t, i] = best
# Out:
# trial 1/3 | iteration 1/40 | picked category: 0 | sampled posterior value = -3.416864692519481
# best = -1.1490256707468238
# trial 1/3 | iteration 2/40 | picked category: 0 | sampled posterior value = -3.45999871733704
# best = -1.1490256707468238
# trial 1/3 | iteration 3/40 | picked category: 0 | sampled posterior value = -2.836179560013244
# best = -1.1490256707468238
# trial 1/3 | iteration 4/40 | picked category: 0 | sampled posterior value = -1.5430162504887215
# best = -1.1490256707468238
# trial 1/3 | iteration 5/40 | picked category: 0 | sampled posterior value = -1.9459069251241963
# best = -1.1490256707468238
# trial 1/3 | iteration 6/40 | picked category: 0 | sampled posterior value = -1.9006616951425856
# best = -1.1490256707468238
# trial 1/3 | iteration 7/40 | picked category: 0 | sampled posterior value = -2.2653489123313415
# best = -1.1490256707468238
# trial 1/3 | iteration 8/40 | picked category: 0 | sampled posterior value = -1.8269090048181167
# best = -1.1490256707468238
# trial 1/3 | iteration 9/40 | picked category: 0 | sampled posterior value = -2.129269677554057
# best = -1.1490256707468238
# trial 1/3 | iteration 10/40 | picked category: 0 | sampled posterior value = -1.9725465037642809
# best = -0.9342138778266897
# trial 1/3 | iteration 11/40 | picked category: 0 | sampled posterior value = -1.4813213903782823
# best = -0.9342138778266897
# trial 1/3 | iteration 12/40 | picked category: 0 | sampled posterior value = -1.8910928802112283
# best = -0.6542871853043057
# trial 1/3 | iteration 13/40 | picked category: 0 | sampled posterior value = -1.693319709356379
# best = -0.6542871853043057
# trial 1/3 | iteration 14/40 | picked category: 0 | sampled posterior value = -1.9343587069940307
# best = -0.6542871853043057
# trial 1/3 | iteration 15/40 | picked category: 0 | sampled posterior value = -1.88550562242545
# best = -0.5478573959128465
# trial 1/3 | iteration 16/40 | picked category: 0 | sampled posterior value = -1.501070995188122
# best = -0.5478573959128465
# trial 1/3 | iteration 17/40 | picked category: 0 | sampled posterior value = -1.2286142274966587
# best = -0.5478573959128465
# trial 1/3 | iteration 18/40 | picked category: 0 | sampled posterior value = -1.1249517835792675
# best = -0.07920316063866695
# trial 1/3 | iteration 19/40 | picked category: 0 | sampled posterior value = -1.1074079280268951
# best = -0.07920316063866695
# trial 1/3 | iteration 20/40 | picked category: 0 | sampled posterior value = -1.4408570362751205
# best = -0.07920316063866695
# trial 1/3 | iteration 21/40 | picked category: 0 | sampled posterior value = -1.1204366250823037
# best = -0.07920316063866695
# trial 1/3 | iteration 22/40 | picked category: 0 | sampled posterior value = -0.9196216969797678
# best = -0.07920316063866695
# trial 1/3 | iteration 23/40 | picked category: 0 | sampled posterior value = -0.9183410284823734
# best = -0.07920316063866695
# trial 1/3 | iteration 24/40 | picked category: 0 | sampled posterior value = -1.0499728694426558
# best = -0.07920316063866695
# trial 1/3 | iteration 25/40 | picked category: 0 | sampled posterior value = -0.984030600360866
# best = -0.07920316063866695
# trial 1/3 | iteration 26/40 | picked category: 0 | sampled posterior value = -0.8913370766335204
# best = -0.07920316063866695
# trial 1/3 | iteration 27/40 | picked category: 0 | sampled posterior value = -0.7359056850245803
# best = -0.07920316063866695
# trial 1/3 | iteration 28/40 | picked category: 0 | sampled posterior value = -0.5536940867267286
# best = -0.07920316063866695
# trial 1/3 | iteration 29/40 | picked category: 0 | sampled posterior value = -0.3406551690334719
# best = -0.07920316063866695
# trial 1/3 | iteration 30/40 | picked category: 0 | sampled posterior value = -0.2244267470901868
# best = -0.07920316063866695
# trial 1/3 | iteration 31/40 | picked category: 0 | sampled posterior value = -0.4278323376440756
# best = -0.07920316063866695
# trial 1/3 | iteration 32/40 | picked category: 0 | sampled posterior value = -0.6158915881459155
# best = -0.07920316063866695
# trial 1/3 | iteration 33/40 | picked category: 0 | sampled posterior value = -0.4365797688341981
# best = -0.07920316063866695
# trial 1/3 | iteration 34/40 | picked category: 0 | sampled posterior value = -0.11748590418951334
# best = -0.07920316063866695
# trial 1/3 | iteration 35/40 | picked category: 0 | sampled posterior value = -0.5193891521832158
# best = -0.07920316063866695
# trial 1/3 | iteration 36/40 | picked category: 0 | sampled posterior value = -0.10700855515357892
# best = -0.07920316063866695
# trial 1/3 | iteration 37/40 | picked category: 0 | sampled posterior value = -0.5122098761137817
# best = -0.07920316063866695
# trial 1/3 | iteration 38/40 | picked category: 0 | sampled posterior value = -0.5368293928782415
# best = -0.07920316063866695
# trial 1/3 | iteration 39/40 | picked category: 0 | sampled posterior value = -0.24303283707257622
# best = -0.07920316063866695
# trial 1/3 | iteration 40/40 | picked category: 0 | sampled posterior value = -0.17334765370257682
# best = -0.07920316063866695
# trial 2/3 | iteration 1/40 | picked category: 0 | sampled posterior value = -4.166180704183087
# best = -3.582613018525319
# trial 2/3 | iteration 2/40 | picked category: 0 | sampled posterior value = -2.54047712061306
# best = -3.582613018525319
# trial 2/3 | iteration 3/40 | picked category: 0 | sampled posterior value = -2.8690695375939277
# best = -3.582613018525319
# trial 2/3 | iteration 4/40 | picked category: 0 | sampled posterior value = -2.3726508263206836
# best = -3.4310119585423178
# trial 2/3 | iteration 5/40 | picked category: 0 | sampled posterior value = -2.7916830051562975
# best = -3.4310119585423178
# trial 2/3 | iteration 6/40 | picked category: 0 | sampled posterior value = -2.81173826884275
# best = -3.4310119585423178
# trial 2/3 | iteration 7/40 | picked category: 0 | sampled posterior value = -2.5952488706860155
# best = -2.65244831474341
# trial 2/3 | iteration 8/40 | picked category: 0 | sampled posterior value = -2.4786706267983707
# best = -2.65244831474341
# trial 2/3 | iteration 9/40 | picked category: 0 | sampled posterior value = -2.7134209016093225
# best = -2.65244831474341
# trial 2/3 | iteration 10/40 | picked category: 0 | sampled posterior value = -2.9133225625217785
# best = -0.16980442141686725
# trial 2/3 | iteration 11/40 | picked category: 0 | sampled posterior value = -1.9425443689863826
# best = -0.10531717482933134
# trial 2/3 | iteration 12/40 | picked category: 0 | sampled posterior value = -0.9108669465297465
# best = -0.10531717482933134
# trial 2/3 | iteration 13/40 | picked category: 0 | sampled posterior value = -1.273431200213107
# best = -0.10531717482933134
# trial 2/3 | iteration 14/40 | picked category: 0 | sampled posterior value = -0.8727543624834748
# best = -0.07692537858079662
# trial 2/3 | iteration 15/40 | picked category: 0 | sampled posterior value = -1.0879914380075
# best = -0.024772657760110395
# trial 2/3 | iteration 16/40 | picked category: 0 | sampled posterior value = -0.7877965219991626
# best = -0.024772657760110395
# trial 2/3 | iteration 17/40 | picked category: 0 | sampled posterior value = -0.49699764322328355
# best = -0.024772657760110395
# trial 2/3 | iteration 18/40 | picked category: 0 | sampled posterior value = -0.38488217638163735
# best = -0.024772657760110395
# trial 2/3 | iteration 19/40 | picked category: 0 | sampled posterior value = -0.12577514969141762
# best = -0.024772657760110395
# trial 2/3 | iteration 20/40 | picked category: 0 | sampled posterior value = -0.4016333749136003
# best = -0.024772657760110395
# trial 2/3 | iteration 21/40 | picked category: 0 | sampled posterior value = 0.12864375386849403
# best = -0.024772657760110395
# trial 2/3 | iteration 22/40 | picked category: 0 | sampled posterior value = -0.19980555124248212
# best = -0.024772657760110395
# trial 2/3 | iteration 23/40 | picked category: 0 | sampled posterior value = -0.47257879534946956
# best = -0.024772657760110395
# trial 2/3 | iteration 24/40 | picked category: 0 | sampled posterior value = -0.24189178444451426
# best = -0.024772657760110395
# trial 2/3 | iteration 25/40 | picked category: 0 | sampled posterior value = -0.34202044592681435
# best = -0.024772657760110395
# trial 2/3 | iteration 26/40 | picked category: 0 | sampled posterior value = -0.15107936451213722
# best = -0.024772657760110395
# trial 2/3 | iteration 27/40 | picked category: 0 | sampled posterior value = -0.3130031803942217
# best = -0.024772657760110395
# trial 2/3 | iteration 28/40 | picked category: 0 | sampled posterior value = -0.8086089188893018
# best = -0.024772657760110395
# trial 2/3 | iteration 29/40 | picked category: 0 | sampled posterior value = -0.3025634461214811
# best = -0.024772657760110395
# trial 2/3 | iteration 30/40 | picked category: 0 | sampled posterior value = 0.014978062585279228
# best = -0.024772657760110395
# trial 2/3 | iteration 31/40 | picked category: 0 | sampled posterior value = -0.053468383508316286
# best = -0.024772657760110395
# trial 2/3 | iteration 32/40 | picked category: 0 | sampled posterior value = -0.25491912784735904
# best = -0.024772657760110395
# trial 2/3 | iteration 33/40 | picked category: 0 | sampled posterior value = -0.17699483105887256
# best = -0.024772657760110395
# trial 2/3 | iteration 34/40 | picked category: 0 | sampled posterior value = -0.6039108319237741
# best = -0.024772657760110395
# trial 2/3 | iteration 35/40 | picked category: 0 | sampled posterior value = -0.22536044236357705
# best = -0.024772657760110395
# trial 2/3 | iteration 36/40 | picked category: 0 | sampled posterior value = -0.18221327927573253
# best = -0.024772657760110395
# trial 2/3 | iteration 37/40 | picked category: 0 | sampled posterior value = -0.09080612359516475
# best = -0.024772657760110395
# trial 2/3 | iteration 38/40 | picked category: 0 | sampled posterior value = -0.0971053830315945
# best = -0.024772657760110395
# trial 2/3 | iteration 39/40 | picked category: 0 | sampled posterior value = -0.24724664366076693
# best = -0.024772657760110395
# trial 2/3 | iteration 40/40 | picked category: 0 | sampled posterior value = -0.2800043144489948
# best = -0.024772657760110395
# trial 3/3 | iteration 1/40 | picked category: 0 | sampled posterior value = -2.213678132109152
# best = -2.6401654357389117
# trial 3/3 | iteration 2/40 | picked category: 0 | sampled posterior value = -1.3624134831407662
# best = -2.6401654357389117
# trial 3/3 | iteration 3/40 | picked category: 0 | sampled posterior value = -1.5720029067833496
# best = -2.6401654357389117
# trial 3/3 | iteration 4/40 | picked category: 0 | sampled posterior value = -2.9246023226392603
# best = -2.6401654357389117
# trial 3/3 | iteration 5/40 | picked category: 0 | sampled posterior value = -3.188547740128915
# best = -2.6401654357389117
# trial 3/3 | iteration 6/40 | picked category: 0 | sampled posterior value = -2.9103967207803914
# best = -2.6401654357389117
# trial 3/3 | iteration 7/40 | picked category: 0 | sampled posterior value = -1.902929697777018
# best = -2.6401654357389117
# trial 3/3 | iteration 8/40 | picked category: 0 | sampled posterior value = -2.692184307996718
# best = -2.6401654357389117
# trial 3/3 | iteration 9/40 | picked category: 0 | sampled posterior value = -2.7080292356857507
# best = -2.6401654357389117
# trial 3/3 | iteration 10/40 | picked category: 0 | sampled posterior value = -2.3434830230601227
# best = -2.6401654357389117
# trial 3/3 | iteration 11/40 | picked category: 0 | sampled posterior value = -2.5886199438657
# best = -2.6401654357389117
# trial 3/3 | iteration 12/40 | picked category: 0 | sampled posterior value = -2.376945203881671
# best = -2.6401654357389117
# trial 3/3 | iteration 13/40 | picked category: 0 | sampled posterior value = -2.384804907227195
# best = -2.6401654357389117
# trial 3/3 | iteration 14/40 | picked category: 0 | sampled posterior value = -2.04205177791789
# best = -2.6401654357389117
# trial 3/3 | iteration 15/40 | picked category: 0 | sampled posterior value = -2.3450408394063427
# best = -2.6401654357389117
# trial 3/3 | iteration 16/40 | picked category: 0 | sampled posterior value = -2.0509847114887054
# best = -2.6401654357389117
# trial 3/3 | iteration 17/40 | picked category: 0 | sampled posterior value = -2.8645058325574597
# best = -0.3954614228412727
# trial 3/3 | iteration 18/40 | picked category: 0 | sampled posterior value = -2.0752475334549354
# best = -0.3954614228412727
# trial 3/3 | iteration 19/40 | picked category: 0 | sampled posterior value = -1.6338675223522912
# best = -0.3954614228412727
# trial 3/3 | iteration 20/40 | picked category: 0 | sampled posterior value = -1.1278227065345816
# best = -0.3954614228412727
# trial 3/3 | iteration 21/40 | picked category: 0 | sampled posterior value = -0.03861065777346706
# best = -0.3954614228412727
# trial 3/3 | iteration 22/40 | picked category: 0 | sampled posterior value = -1.7710886148381
# best = -0.3954614228412727
# trial 3/3 | iteration 23/40 | picked category: 0 | sampled posterior value = -0.5446497969428006
# best = -0.3954614228412727
# trial 3/3 | iteration 24/40 | picked category: 0 | sampled posterior value = -0.6469956347944495
# best = -0.3954614228412727
# trial 3/3 | iteration 25/40 | picked category: 0 | sampled posterior value = -0.9222090465585762
# best = -0.3954614228412727
# trial 3/3 | iteration 26/40 | picked category: 0 | sampled posterior value = -1.190542106943079
# best = -0.3954614228412727
# trial 3/3 | iteration 27/40 | picked category: 0 | sampled posterior value = -0.8743967341969884
# best = -0.3517608180365781
# trial 3/3 | iteration 28/40 | picked category: 0 | sampled posterior value = -0.7701964485498867
# best = -0.3517608180365781
# trial 3/3 | iteration 29/40 | picked category: 0 | sampled posterior value = -0.5236590071642486
# best = -0.2599220959406954
# trial 3/3 | iteration 30/40 | picked category: 0 | sampled posterior value = -0.21893630926850494
# best = -0.2599220959406954
# trial 3/3 | iteration 31/40 | picked category: 0 | sampled posterior value = -0.49834456350296474
# best = -0.23279195608185832
# trial 3/3 | iteration 32/40 | picked category: 0 | sampled posterior value = -0.28587555537065534
# best = -0.23279195608185832
# trial 3/3 | iteration 33/40 | picked category: 0 | sampled posterior value = -0.3289846008298387
# best = -0.13188580968525487
# trial 3/3 | iteration 34/40 | picked category: 0 | sampled posterior value = -0.17146209748847352
# best = -0.13188580968525487
# trial 3/3 | iteration 35/40 | picked category: 0 | sampled posterior value = -0.5525973899087394
# best = -0.13188580968525487
# trial 3/3 | iteration 36/40 | picked category: 0 | sampled posterior value = -0.29357481725986245
# best = -0.13188580968525487
# trial 3/3 | iteration 37/40 | picked category: 0 | sampled posterior value = -0.07227340460085416
# best = -0.13188580968525487
# trial 3/3 | iteration 38/40 | picked category: 0 | sampled posterior value = -0.5479410056702748
# best = -0.05509715399424708
# trial 3/3 | iteration 39/40 | picked category: 0 | sampled posterior value = -0.12811954732991707
# best = -0.05509715399424708
# trial 3/3 | iteration 40/40 | picked category: 0 | sampled posterior value = -0.47420157857334766
# best = -0.05509715399424708
