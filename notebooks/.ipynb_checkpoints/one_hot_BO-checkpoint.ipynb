# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"\\scripts")

# %%
import torch
tkwargs = {"dtype": torch.double,
           "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
#            "device": torch.device("cpu")
          }

from botorch.acquisition.monte_carlo import qExpectedImprovement
from botorch.sampling.samplers import SobolQMCNormalSampler
import matplotlib.pyplot as plt

from one_hot_BO_utils import *

# %%
# global parameters

d = 5
m = 2*(d+1)
C = 5
BOUNDS = torch.tensor([[-1.0]*d,
                       [3.0]*d]).to(**tkwargs)
BOUNDS_ACQF = torch.tensor([[0.0]*C + [-1.0]*d,
                            [1.0]*C + [3.0]*d]).to(**tkwargs)

N_CANDIDATES = 1
NUM_MC_SAMPLES = 256
qmc_sampler = SobolQMCNormalSampler(num_samples=NUM_MC_SAMPLES)

N_TRIALS = 3e
N_ITERS = 100

# %%
NU = 1.5

# BO LOOP

best_values = torch.empty(N_TRIALS, N_ITERS + 1, **tkwargs)

for t in range(N_TRIALS):
    
    # generate starting dataset
    train_X = generate_X(m, C, BOUNDS, seed=t)
    train_y = modified_neg_ackley(train_X, C)
    best_values[t, 0] = train_y.max().item()

    
    for i in range(1, N_ITERS + 1):
        
        print(f"trial {t+1}/{N_TRIALS} | iteration {i}/{N_ITERS}")
        
        new_X = []
        
        for j in range(N_CANDIDATES):
            
            # set X_pending
            if len(new_X) > 0:
                X_pending = torch.cat(new_X, dim=0)
            else:
                X_pending = None
        
            # normalize X
            train_X_normalized = normalize_with_bounds(train_X, C, BOUNDS)
        
            # initialize model
            model = initialize_models(train_X_normalized, train_y, nu=NU)
            
            # define acqf
            acqf = qExpectedImprovement(model=model, 
                                        best_f=train_y.max(),
                                        sampler=qmc_sampler,
                                        X_pending=X_pending)
        
            # get candidates
            X_picked = get_candidate(acqf, BOUNDS_ACQF, C)
            new_X.append(X_picked)
            
        new_X = torch.cat(new_X, dim=0).to(**tkwargs)
        
        # denormalize candidates
        new_X = denormalize_with_bounds(new_X, C, BOUNDS)
        
        # evaluate objective
        new_y = modified_neg_ackley(new_X, C).to(**tkwargs)
        
        # update train_X and train_y
        train_X = torch.cat([train_X, new_X], dim=0)
        train_y = torch.cat([train_y, new_y], dim=0)
        
        # update best values
        best = train_y.max().item()
        print(f"best = {best}")
        best_values[t, i] = best
# Out:
# trial 1/3 | iteration 1/100
# best = -3.9752081875628105
# trial 1/3 | iteration 2/100
# best = -3.9752081875628105
# trial 1/3 | iteration 3/100
# best = -1.5358816472964496
# trial 1/3 | iteration 4/100
# best = -1.5358816472964496
# trial 1/3 | iteration 5/100
# best = -1.5358816472964496
# trial 1/3 | iteration 6/100
# best = -1.5358816472964496
# trial 1/3 | iteration 7/100
# best = -1.5358816472964496
# trial 1/3 | iteration 8/100
# best = -1.5358816472964496
# trial 1/3 | iteration 9/100
# best = -1.5358816472964496
# trial 1/3 | iteration 10/100
# best = -1.5358816472964496
# trial 1/3 | iteration 11/100
# best = -1.5358816472964496
# trial 1/3 | iteration 12/100
# best = -1.5358816472964496
# trial 1/3 | iteration 13/100
# best = -1.5358816472964496
# trial 1/3 | iteration 14/100
# best = -1.5358816472964496
# trial 1/3 | iteration 15/100
# best = -1.5358816472964496
# trial 1/3 | iteration 16/100
# best = -1.5358816472964496
# trial 1/3 | iteration 17/100
# best = -1.5358816472964496
# trial 1/3 | iteration 18/100
# best = -1.5358816472964496
# trial 1/3 | iteration 19/100
# best = -1.5358816472964496
# trial 1/3 | iteration 20/100
# best = -1.5358816472964496
# trial 1/3 | iteration 21/100
# best = -1.5358816472964496
# trial 1/3 | iteration 22/100
# best = -1.5358816472964496
# trial 1/3 | iteration 23/100
# best = -1.5358816472964496
# trial 1/3 | iteration 24/100
# best = -1.5358816472964496
# trial 1/3 | iteration 25/100
# best = -1.5358816472964496
# trial 1/3 | iteration 26/100
# best = -1.5358816472964496
# trial 1/3 | iteration 27/100
# best = -1.5358816472964496
# trial 1/3 | iteration 28/100
# best = -1.5358816472964496
# trial 1/3 | iteration 29/100
# best = -1.5358816472964496
# trial 1/3 | iteration 30/100
# best = -1.5358816472964496
# trial 1/3 | iteration 31/100
# best = -1.5358816472964496
# trial 1/3 | iteration 32/100
# best = -1.5358816472964496
# trial 1/3 | iteration 33/100
# best = -1.5358816472964496
# trial 1/3 | iteration 34/100
# best = -1.5358816472964496
# trial 1/3 | iteration 35/100
# best = -1.5358816472964496
# trial 1/3 | iteration 36/100
# best = -1.5358816472964496
# trial 1/3 | iteration 37/100
# best = -1.5358816472964496
# trial 1/3 | iteration 38/100
# best = -1.5358816472964496
# trial 1/3 | iteration 39/100
# best = -1.5358816472964496
# trial 1/3 | iteration 40/100
# best = -1.5358816472964496
# trial 1/3 | iteration 41/100
# best = -1.5358816472964496
# trial 1/3 | iteration 42/100
# best = -1.5358816472964496
# trial 1/3 | iteration 43/100
# best = -1.5358816472964496
# trial 1/3 | iteration 44/100
# best = -1.5358816472964496
# trial 1/3 | iteration 45/100
# best = -1.5358816472964496
# trial 1/3 | iteration 46/100
# best = -1.5358816472964496
# trial 1/3 | iteration 47/100
# best = -1.5358816472964496
# trial 1/3 | iteration 48/100
# best = -1.5358816472964496
# trial 1/3 | iteration 49/100
# best = -1.5358816472964496
# trial 1/3 | iteration 50/100
# best = -1.5358816472964496
# trial 1/3 | iteration 51/100
# best = -1.5358816472964496
# trial 1/3 | iteration 52/100
# best = -1.5358816472964496
# trial 1/3 | iteration 53/100
# best = -1.5358816472964496
# trial 1/3 | iteration 54/100
# best = -1.5358816472964496
# trial 1/3 | iteration 55/100
# best = -1.5358816472964496
# trial 1/3 | iteration 56/100
# best = -1.5358816472964496
# trial 1/3 | iteration 57/100
# best = -1.5358816472964496
# trial 1/3 | iteration 58/100
# best = -1.5358816472964496
# trial 1/3 | iteration 59/100
# best = -1.5358816472964496
# trial 1/3 | iteration 60/100
# best = -1.5358816472964496
# trial 1/3 | iteration 61/100
# best = -1.5358816472964496
# trial 1/3 | iteration 62/100
# best = -1.5358816472964496
# trial 1/3 | iteration 63/100
# best = -1.5358816472964496
# trial 1/3 | iteration 64/100
# best = -1.5358816472964496
# trial 1/3 | iteration 65/100
# best = -1.5358816472964496
# trial 1/3 | iteration 66/100
# best = -1.5358816472964496
# trial 1/3 | iteration 67/100
# best = -1.5358816472964496
# trial 1/3 | iteration 68/100
# best = -1.5358816472964496
# trial 1/3 | iteration 69/100
# best = -1.5358816472964496
# trial 1/3 | iteration 70/100
# best = -1.5358816472964496
# trial 1/3 | iteration 71/100
# best = -1.5358816472964496
# trial 1/3 | iteration 72/100
# best = -1.5358816472964496
# trial 1/3 | iteration 73/100
# best = -1.5358816472964496
# trial 1/3 | iteration 74/100
# best = -1.5358816472964496
# trial 1/3 | iteration 75/100
# best = -1.5358816472964496
# trial 1/3 | iteration 76/100
# best = -1.5358816472964496
# trial 1/3 | iteration 77/100
# best = -1.5358816472964496
# trial 1/3 | iteration 78/100
# best = -1.5358816472964496
# trial 1/3 | iteration 79/100
# best = -1.5358816472964496
# trial 1/3 | iteration 80/100
# best = -1.5358816472964496
# trial 1/3 | iteration 81/100
# best = -1.5358816472964496
# trial 1/3 | iteration 82/100
# best = -1.5358816472964496
# trial 1/3 | iteration 83/100
# best = -1.5358816472964496
# trial 1/3 | iteration 84/100
# best = -1.5358816472964496
# trial 1/3 | iteration 85/100
# best = -1.5358816472964496
# trial 1/3 | iteration 86/100
# best = -1.5358816472964496
# trial 1/3 | iteration 87/100
# best = -1.5358816472964496
# trial 1/3 | iteration 88/100
# best = -1.5358816472964496
# trial 1/3 | iteration 89/100
# best = -1.5358816472964496
# trial 1/3 | iteration 90/100
# best = -1.5358816472964496
# trial 1/3 | iteration 91/100
# best = -1.5358816472964496
# trial 1/3 | iteration 92/100
# best = -1.5358816472964496
# trial 1/3 | iteration 93/100
# best = -1.5358816472964496
# trial 1/3 | iteration 94/100
# best = -1.5358816472964496
# trial 1/3 | iteration 95/100
# best = -1.5358816472964496
# trial 1/3 | iteration 96/100
# best = -1.5358816472964496
# trial 1/3 | iteration 97/100
# best = -1.5358816472964496
# trial 1/3 | iteration 98/100
# best = -1.5358816472964496
# trial 1/3 | iteration 99/100
# best = -1.5358816472964496
# trial 1/3 | iteration 100/100
# best = -1.5358816472964496
# trial 2/3 | iteration 1/100
# best = -3.7311497467272052
# trial 2/3 | iteration 2/100
# best = -3.7311497467272052
# trial 2/3 | iteration 3/100
# best = -3.7311497467272052
# trial 2/3 | iteration 4/100
# best = -3.7311497467272052
# trial 2/3 | iteration 5/100
# best = -3.7311497467272052
# trial 2/3 | iteration 6/100
# best = -3.7311497467272052
# trial 2/3 | iteration 7/100
# best = -3.7311497467272052
# trial 2/3 | iteration 8/100
# best = -3.7311497467272052
# trial 2/3 | iteration 9/100
# best = -3.7311497467272052
# trial 2/3 | iteration 10/100
# best = -3.7311497467272052
# trial 2/3 | iteration 11/100
# best = -3.7311497467272052
# trial 2/3 | iteration 12/100
# best = -3.7311497467272052
# trial 2/3 | iteration 13/100
# best = -3.7311497467272052
# trial 2/3 | iteration 14/100
# best = -3.3513567833328506
# trial 2/3 | iteration 15/100
# best = -3.3513567833328506
# trial 2/3 | iteration 16/100
# best = -3.3513567833328506
# trial 2/3 | iteration 17/100
# best = -3.3513567833328506
# trial 2/3 | iteration 18/100
# best = -3.3513567833328506
# trial 2/3 | iteration 19/100
# best = -3.3513567833328506
# trial 2/3 | iteration 20/100
# best = -3.3513567833328506
# trial 2/3 | iteration 21/100
# best = -3.3513567833328506
# trial 2/3 | iteration 22/100
# best = -3.3513567833328506
# trial 2/3 | iteration 23/100
# best = -3.3513567833328506
# trial 2/3 | iteration 24/100
# best = -1.6981156442253895
# trial 2/3 | iteration 25/100
# best = -1.6981156442253895
# trial 2/3 | iteration 26/100
# best = -1.6981156442253895
# trial 2/3 | iteration 27/100
# best = -1.6981156442253895
# trial 2/3 | iteration 28/100
# best = -1.6981156442253895
# trial 2/3 | iteration 29/100
# best = -1.6981156442253895
# trial 2/3 | iteration 30/100
# best = -1.6981156442253895
# trial 2/3 | iteration 31/100
# best = -1.6981156442253895
# trial 2/3 | iteration 32/100
# best = -1.6981156442253895
# trial 2/3 | iteration 33/100
# best = -1.6981156442253895
# trial 2/3 | iteration 34/100
# best = -1.6981156442253895
# trial 2/3 | iteration 35/100
# best = -1.6981156442253895
# trial 2/3 | iteration 36/100
# best = -1.6981156442253895
# trial 2/3 | iteration 37/100
# best = -1.6981156442253895
# trial 2/3 | iteration 38/100
# best = -1.6981156442253895
# trial 2/3 | iteration 39/100
# best = -1.6981156442253895
# trial 2/3 | iteration 40/100
# best = -1.6981156442253895
# trial 2/3 | iteration 41/100
# best = -1.6981156442253895
# trial 2/3 | iteration 42/100
# best = -1.6981156442253895
# trial 2/3 | iteration 43/100
# best = -1.6981156442253895
# trial 2/3 | iteration 44/100
# best = -1.6981156442253895
# trial 2/3 | iteration 45/100
# best = -1.6981156442253895
# trial 2/3 | iteration 46/100
# best = -1.6981156442253895
# trial 2/3 | iteration 47/100
# best = -1.6981156442253895
# trial 2/3 | iteration 48/100
# best = -1.6981156442253895
# trial 2/3 | iteration 49/100
# best = -1.6981156442253895
# trial 2/3 | iteration 50/100
# best = -1.6981156442253895
# trial 2/3 | iteration 51/100
# best = -1.6981156442253895
# trial 2/3 | iteration 52/100
# best = -1.6981156442253895
# trial 2/3 | iteration 53/100
# best = -1.6981156442253895
# trial 2/3 | iteration 54/100
# best = -1.6981156442253895
# trial 2/3 | iteration 55/100
# best = -1.6981156442253895
# trial 2/3 | iteration 56/100
# best = -1.6981156442253895
# trial 2/3 | iteration 57/100
# best = -1.6981156442253895
# trial 2/3 | iteration 58/100
# best = -1.6981156442253895
# trial 2/3 | iteration 59/100
# best = -1.6981156442253895
# trial 2/3 | iteration 60/100
# best = -1.6981156442253895
# trial 2/3 | iteration 61/100
# best = -1.6981156442253895
# trial 2/3 | iteration 62/100
# best = -1.6981156442253895
# trial 2/3 | iteration 63/100
# best = -1.6981156442253895
# trial 2/3 | iteration 64/100
# best = -1.6981156442253895
# trial 2/3 | iteration 65/100
# best = -1.6981156442253895
# trial 2/3 | iteration 66/100
# best = -1.6981156442253895
# trial 2/3 | iteration 67/100
# best = -1.6981156442253895
# trial 2/3 | iteration 68/100
# best = -1.6981156442253895
# trial 2/3 | iteration 69/100
# best = -1.6981156442253895
# trial 2/3 | iteration 70/100
# best = -1.6981156442253895
# trial 2/3 | iteration 71/100
# best = -1.6981156442253895
# trial 2/3 | iteration 72/100
# best = -1.6981156442253895
# trial 2/3 | iteration 73/100
# best = -1.6981156442253895
# trial 2/3 | iteration 74/100
# best = -1.6981156442253895
# trial 2/3 | iteration 75/100
# best = -1.6981156442253895
# trial 2/3 | iteration 76/100
# best = -1.6981156442253895
# trial 2/3 | iteration 77/100
# best = -1.6981156442253895
# trial 2/3 | iteration 78/100
# best = -1.6981156442253895
# trial 2/3 | iteration 79/100
# best = -1.6981156442253895
# trial 2/3 | iteration 80/100
# best = -1.6981156442253895
# trial 2/3 | iteration 81/100
# best = -1.6981156442253895
# trial 2/3 | iteration 82/100
# best = -1.6981156442253895
# trial 2/3 | iteration 83/100
# best = -1.6981156442253895
# trial 2/3 | iteration 84/100
# best = -1.6981156442253895
# trial 2/3 | iteration 85/100
# best = -1.6981156442253895
# trial 2/3 | iteration 86/100
# best = -1.6981156442253895
# trial 2/3 | iteration 87/100
# best = -1.6981156442253895
# trial 2/3 | iteration 88/100
# best = -1.6981156442253895
# trial 2/3 | iteration 89/100
# best = -1.6981156442253895
# trial 2/3 | iteration 90/100
# best = -1.6981156442253895
# trial 2/3 | iteration 91/100
# best = -1.6981156442253895
# trial 2/3 | iteration 92/100
# best = -1.6981156442253895
# trial 2/3 | iteration 93/100
# best = -1.6981156442253895
# trial 2/3 | iteration 94/100
# best = -1.6981156442253895
# trial 2/3 | iteration 95/100
# best = -1.6981156442253895
# trial 2/3 | iteration 96/100
# best = -1.6981156442253895
# trial 2/3 | iteration 97/100
# best = -1.6981156442253895
# trial 2/3 | iteration 98/100
# best = -1.6981156442253895
# trial 2/3 | iteration 99/100
# best = -1.6981156442253895
# trial 2/3 | iteration 100/100
# best = -1.6981156442253895
# trial 3/3 | iteration 1/100
# best = -2.5369190203732797
# trial 3/3 | iteration 2/100
# best = -2.5369190203732797
# trial 3/3 | iteration 3/100
# best = -2.5369190203732797
# trial 3/3 | iteration 4/100
# best = -2.5369190203732797
# trial 3/3 | iteration 5/100
# best = -2.5369190203732797
# trial 3/3 | iteration 6/100
# best = -2.5369190203732797
# trial 3/3 | iteration 7/100
# best = -2.5369190203732797
# trial 3/3 | iteration 8/100
# best = -2.5369190203732797
# trial 3/3 | iteration 9/100
# best = -2.5369190203732797
# trial 3/3 | iteration 10/100
# best = -2.5369190203732797
# trial 3/3 | iteration 11/100
# best = -0.5149220689434633
# trial 3/3 | iteration 12/100
# best = -0.5149220689434633
# trial 3/3 | iteration 13/100
# best = -0.5149220689434633
# trial 3/3 | iteration 14/100
# best = -0.5149220689434633
# trial 3/3 | iteration 15/100
# best = -0.5149220689434633
# trial 3/3 | iteration 16/100
# best = -0.5149220689434633
# trial 3/3 | iteration 17/100
# best = -0.5149220689434633
# trial 3/3 | iteration 18/100
# best = -0.5149220689434633
# trial 3/3 | iteration 19/100
# best = -0.5149220689434633
# trial 3/3 | iteration 20/100
# best = -0.5149220689434633
# trial 3/3 | iteration 21/100
# best = -0.5149220689434633
# trial 3/3 | iteration 22/100
# best = -0.5149220689434633
# trial 3/3 | iteration 23/100
# best = -0.5149220689434633
# trial 3/3 | iteration 24/100
# best = -0.5149220689434633
# trial 3/3 | iteration 25/100
# best = -0.5149220689434633
# trial 3/3 | iteration 26/100
# best = -0.5149220689434633
# trial 3/3 | iteration 27/100
# best = -0.5149220689434633
# trial 3/3 | iteration 28/100
# best = -0.5149220689434633
# trial 3/3 | iteration 29/100
# best = -0.5149220689434633
# trial 3/3 | iteration 30/100
# best = -0.5149220689434633
# trial 3/3 | iteration 31/100
# best = -0.5149220689434633
# trial 3/3 | iteration 32/100
# best = -0.5149220689434633
# trial 3/3 | iteration 33/100
# best = -0.5149220689434633
# trial 3/3 | iteration 34/100
# best = -0.5149220689434633
# trial 3/3 | iteration 35/100
# best = -0.5149220689434633
# trial 3/3 | iteration 36/100
# best = -0.5149220689434633
# trial 3/3 | iteration 37/100
# best = -0.5149220689434633
# trial 3/3 | iteration 38/100
# best = -0.5149220689434633
# trial 3/3 | iteration 39/100
# best = -0.5149220689434633
# trial 3/3 | iteration 40/100
# best = -0.5149220689434633
# trial 3/3 | iteration 41/100
# best = -0.5149220689434633
# trial 3/3 | iteration 42/100
# best = -0.5149220689434633
# trial 3/3 | iteration 43/100
# best = -0.5149220689434633
# trial 3/3 | iteration 44/100
# best = -0.5149220689434633
# trial 3/3 | iteration 45/100
# best = -0.5149220689434633
# trial 3/3 | iteration 46/100
# best = -0.5149220689434633
# trial 3/3 | iteration 47/100
# best = -0.5149220689434633
# trial 3/3 | iteration 48/100
# best = -0.5149220689434633
# trial 3/3 | iteration 49/100
# best = -0.5149220689434633
# trial 3/3 | iteration 50/100
# best = -0.5149220689434633
# trial 3/3 | iteration 51/100
# best = -0.5149220689434633
# trial 3/3 | iteration 52/100
# best = -0.5149220689434633
# trial 3/3 | iteration 53/100
# best = -0.5149220689434633
# trial 3/3 | iteration 54/100
# best = -0.5149220689434633
# trial 3/3 | iteration 55/100
# best = -0.5149220689434633
# trial 3/3 | iteration 56/100
# best = -0.5149220689434633
# trial 3/3 | iteration 57/100
# best = -0.5149220689434633
# trial 3/3 | iteration 58/100
# best = -0.5149220689434633
# trial 3/3 | iteration 59/100
# best = -0.5149220689434633
# trial 3/3 | iteration 60/100
# best = -0.5149220689434633
# trial 3/3 | iteration 61/100
# best = -0.5149220689434633
# trial 3/3 | iteration 62/100
# best = -0.5149220689434633
# trial 3/3 | iteration 63/100
# best = -0.5149220689434633
# trial 3/3 | iteration 64/100
# best = -0.5149220689434633
# trial 3/3 | iteration 65/100
# best = -0.5149220689434633
# trial 3/3 | iteration 66/100
# best = -0.5149220689434633
# trial 3/3 | iteration 67/100
# best = -0.5149220689434633
# trial 3/3 | iteration 68/100
# best = -0.5149220689434633
# trial 3/3 | iteration 69/100
# best = -0.5149220689434633
# trial 3/3 | iteration 70/100
# best = -0.5149220689434633
# trial 3/3 | iteration 71/100
# best = -0.5149220689434633
# trial 3/3 | iteration 72/100
# best = -0.5149220689434633
# trial 3/3 | iteration 73/100
# best = -0.5149220689434633
# trial 3/3 | iteration 74/100
# best = -0.5149220689434633
# trial 3/3 | iteration 75/100
# best = -0.5149220689434633
# trial 3/3 | iteration 76/100
# best = -0.5149220689434633
# trial 3/3 | iteration 77/100
# best = -0.5149220689434633
# trial 3/3 | iteration 78/100
# best = -0.5149220689434633
# trial 3/3 | iteration 79/100
# best = -0.5149220689434633
# trial 3/3 | iteration 80/100
# best = -0.5149220689434633
# trial 3/3 | iteration 81/100
# best = -0.5149220689434633
# trial 3/3 | iteration 82/100
# best = -0.5149220689434633
# trial 3/3 | iteration 83/100
# best = -0.5149220689434633
# trial 3/3 | iteration 84/100
# best = -0.5149220689434633
# trial 3/3 | iteration 85/100
# best = -0.5149220689434633
# trial 3/3 | iteration 86/100
# best = -0.5149220689434633
# trial 3/3 | iteration 87/100
# best = -0.5149220689434633
# trial 3/3 | iteration 88/100
# best = -0.5149220689434633
# trial 3/3 | iteration 89/100
# best = -0.5149220689434633
# trial 3/3 | iteration 90/100
# best = -0.5149220689434633
# trial 3/3 | iteration 91/100
# best = -0.5149220689434633
# trial 3/3 | iteration 92/100
# best = -0.5149220689434633
# trial 3/3 | iteration 93/100
# best = -0.5149220689434633
# trial 3/3 | iteration 94/100
# best = -0.5149220689434633
# trial 3/3 | iteration 95/100
# best = -0.5149220689434633
# trial 3/3 | iteration 96/100
# best = -0.5149220689434633
# trial 3/3 | iteration 97/100
# best = -0.5149220689434633
# trial 3/3 | iteration 98/100
# best = -0.5149220689434633
# trial 3/3 | iteration 99/100
# best = -0.5149220689434633
# trial 3/3 | iteration 100/100
# best = -0.5149220689434633

# %%
NU = 0.5

# BO LOOP

best_values_2 = torch.empty(N_TRIALS, N_ITERS + 1, **tkwargs)

for t in range(N_TRIALS):
    
    # generate starting dataset
    train_X = generate_X(m, C, BOUNDS, seed=t)
    train_y = modified_neg_ackley(train_X, C)
    best_values_2[t, 0] = train_y.max().item()

    
    for i in range(1, N_ITERS + 1):
        
        print(f"trial {t+1}/{N_TRIALS} | iteration {i}/{N_ITERS}")
        
        new_X = []
        
        for j in range(N_CANDIDATES):
            
            # set X_pending
            if len(new_X) > 0:
                X_pending = torch.cat(new_X, dim=0)
            else:
                X_pending = None
        
            # normalize X
            train_X_normalized = normalize_with_bounds(train_X, C, BOUNDS)
        
            # initialize model
            model = initialize_models(train_X_normalized, train_y, nu=NU)
            
            # define acqf
            acqf = qExpectedImprovement(model=model, 
                                        best_f=train_y.max(),
                                        sampler=qmc_sampler,
                                        X_pending=X_pending)
        
            # get candidates
            X_picked = get_candidate(acqf, BOUNDS_ACQF, C)
            new_X.append(X_picked)
            
        new_X = torch.cat(new_X, dim=0).to(**tkwargs)
        
        # denormalize candidates
        new_X = denormalize_with_bounds(new_X, C, BOUNDS)
        
        # evaluate objective
        new_y = modified_neg_ackley(new_X, C).to(**tkwargs)
        
        # update train_X and train_y
        train_X = torch.cat([train_X, new_X], dim=0)
        train_y = torch.cat([train_y, new_y], dim=0)
        
        # update best values
        best = train_y.max().item()
        print(f"best = {best}")
        best_values_2[t, i] = best
# Out:
# trial 1/3 | iteration 1/100
# best = -3.6298479288122043
# trial 1/3 | iteration 2/100
# best = -3.6298479288122043
# trial 1/3 | iteration 3/100
# best = -3.6298479288122043
# trial 1/3 | iteration 4/100
# best = -1.5662925807573953
# trial 1/3 | iteration 5/100
# best = -1.5662925807573953
# trial 1/3 | iteration 6/100
# best = -1.5662925807573953
# trial 1/3 | iteration 7/100
# best = -1.5662925807573953
# trial 1/3 | iteration 8/100
# best = -1.1529840598662067
# trial 1/3 | iteration 9/100
# best = -1.1529840598662067
# trial 1/3 | iteration 10/100
# best = -1.1529840598662067
# trial 1/3 | iteration 11/100
# best = -1.1529840598662067
# trial 1/3 | iteration 12/100
# best = -1.1529840598662067
# trial 1/3 | iteration 13/100
# best = -1.1529840598662067
# trial 1/3 | iteration 14/100
# best = -0.2473208402216831
# trial 1/3 | iteration 15/100
# best = -0.2473208402216831
# trial 1/3 | iteration 16/100
# best = -0.2473208402216831
# trial 1/3 | iteration 17/100
# best = -0.2473208402216831
# trial 1/3 | iteration 18/100
# best = -0.2473208402216831
# trial 1/3 | iteration 19/100
# best = -0.2473208402216831
# trial 1/3 | iteration 20/100
# best = -0.2473208402216831
# trial 1/3 | iteration 21/100
# best = -0.2473208402216831
# trial 1/3 | iteration 22/100
# best = -0.2473208402216831
# trial 1/3 | iteration 23/100
# best = -0.2473208402216831
# trial 1/3 | iteration 24/100
# best = -0.2473208402216831
# trial 1/3 | iteration 25/100
# best = -0.2473208402216831
# trial 1/3 | iteration 26/100
# best = -0.2473208402216831
# trial 1/3 | iteration 27/100
# best = -0.2473208402216831
# trial 1/3 | iteration 28/100
# best = -0.2473208402216831
# trial 1/3 | iteration 29/100
# best = -0.2473208402216831
# trial 1/3 | iteration 30/100
# best = -0.2473208402216831
# trial 1/3 | iteration 31/100
# best = -0.2473208402216831
# trial 1/3 | iteration 32/100
# best = -0.2473208402216831
# trial 1/3 | iteration 33/100
# best = -0.2473208402216831
# trial 1/3 | iteration 34/100
# best = -0.2473208402216831
# trial 1/3 | iteration 35/100
# best = -0.2473208402216831
# trial 1/3 | iteration 36/100
# best = -0.2473208402216831
# trial 1/3 | iteration 37/100
# best = -0.2473208402216831
# trial 1/3 | iteration 38/100
# best = -0.2473208402216831
# trial 1/3 | iteration 39/100
# best = -0.2473208402216831
# trial 1/3 | iteration 40/100
# best = -0.2473208402216831
# trial 1/3 | iteration 41/100
# best = -0.2473208402216831
# trial 1/3 | iteration 42/100
# best = -0.2473208402216831
# trial 1/3 | iteration 43/100
# best = -0.2473208402216831
# trial 1/3 | iteration 44/100
# best = -0.2473208402216831
# trial 1/3 | iteration 45/100
# best = -0.2473208402216831
# trial 1/3 | iteration 46/100
# best = -0.2473208402216831
# trial 1/3 | iteration 47/100
# best = -0.2473208402216831
# trial 1/3 | iteration 48/100
# best = -0.2473208402216831
# trial 1/3 | iteration 49/100
# best = -0.2473208402216831
# trial 1/3 | iteration 50/100
# best = -0.2473208402216831
# trial 1/3 | iteration 51/100
# best = -0.2473208402216831
# trial 1/3 | iteration 52/100
# best = -0.2473208402216831
# trial 1/3 | iteration 53/100
# best = -0.2473208402216831
# trial 1/3 | iteration 54/100
# best = -0.2473208402216831
# trial 1/3 | iteration 55/100
# best = -0.2473208402216831
# trial 1/3 | iteration 56/100
# best = -0.2473208402216831
# trial 1/3 | iteration 57/100
# best = -0.2473208402216831
# trial 1/3 | iteration 58/100
# best = -0.2473208402216831
# trial 1/3 | iteration 59/100
# best = -0.2473208402216831
# trial 1/3 | iteration 60/100
# best = -0.2473208402216831
# trial 1/3 | iteration 61/100
# best = -0.2473208402216831
# trial 1/3 | iteration 62/100
# best = -0.2473208402216831
# trial 1/3 | iteration 63/100
# best = -0.2473208402216831
# trial 1/3 | iteration 64/100
# best = -0.2473208402216831
# trial 1/3 | iteration 65/100
# best = -0.2473208402216831
# trial 1/3 | iteration 66/100
# best = -0.2473208402216831
# trial 1/3 | iteration 67/100
# best = -0.2473208402216831
# trial 1/3 | iteration 68/100
# best = -0.2473208402216831
# trial 1/3 | iteration 69/100
# best = -0.2473208402216831
# trial 1/3 | iteration 70/100
# best = -0.2473208402216831
# trial 1/3 | iteration 71/100
# best = -0.2473208402216831
# trial 1/3 | iteration 72/100
# best = -0.2473208402216831
# trial 1/3 | iteration 73/100
# best = -0.2473208402216831
# trial 1/3 | iteration 74/100
# best = -0.2473208402216831
# trial 1/3 | iteration 75/100
# best = -0.2473208402216831
# trial 1/3 | iteration 76/100
# best = -0.2473208402216831
# trial 1/3 | iteration 77/100
# best = -0.2473208402216831
# trial 1/3 | iteration 78/100
# best = -0.2473208402216831
# trial 1/3 | iteration 79/100
# best = -0.2473208402216831
# trial 1/3 | iteration 80/100
# best = -0.2473208402216831
# trial 1/3 | iteration 81/100
# best = -0.2473208402216831
# trial 1/3 | iteration 82/100
# best = -0.2473208402216831
# trial 1/3 | iteration 83/100
# best = -0.2473208402216831
# trial 1/3 | iteration 84/100
# best = -0.2473208402216831
# trial 1/3 | iteration 85/100
# best = -0.2473208402216831
# trial 1/3 | iteration 86/100
# best = -0.2473208402216831
# trial 1/3 | iteration 87/100
# best = -0.2473208402216831
# trial 1/3 | iteration 88/100
# best = -0.2473208402216831
# trial 1/3 | iteration 89/100
# best = -0.2473208402216831
# trial 1/3 | iteration 90/100
# best = -0.2473208402216831
# trial 1/3 | iteration 91/100
# best = -0.2473208402216831
# trial 1/3 | iteration 92/100
# best = -0.2473208402216831
# trial 1/3 | iteration 93/100
# best = -0.2473208402216831
# trial 1/3 | iteration 94/100
# best = -0.2473208402216831
# trial 1/3 | iteration 95/100
# best = -0.2473208402216831
# trial 1/3 | iteration 96/100
# best = -0.2473208402216831
# trial 1/3 | iteration 97/100
# best = -0.2473208402216831
# trial 1/3 | iteration 98/100
# best = -0.2473208402216831
# trial 1/3 | iteration 99/100
# best = -0.2473208402216831
# trial 1/3 | iteration 100/100
# best = -0.2473208402216831
# trial 2/3 | iteration 1/100
# best = -3.0455353994861487
# trial 2/3 | iteration 2/100
# best = -3.0455353994861487
# trial 2/3 | iteration 3/100
# best = -2.842179243527337
# trial 2/3 | iteration 4/100
# best = -1.6112664759883377
# trial 2/3 | iteration 5/100
# best = -1.6112664759883377
# trial 2/3 | iteration 6/100
# best = -1.6112664759883377
# trial 2/3 | iteration 7/100
# best = -1.6112664759883377
# trial 2/3 | iteration 8/100
# best = -1.6112664759883377
# trial 2/3 | iteration 9/100
# best = -1.6112664759883377
# trial 2/3 | iteration 10/100
# best = -1.6112664759883377
# trial 2/3 | iteration 11/100
# best = -1.6112664759883377
# trial 2/3 | iteration 12/100
# best = -1.6112664759883377
# trial 2/3 | iteration 13/100
# best = -1.6112664759883377
# trial 2/3 | iteration 14/100
# best = -1.6112664759883377
# trial 2/3 | iteration 15/100
# best = -1.6112664759883377
# trial 2/3 | iteration 16/100
# best = -1.6112664759883377
# trial 2/3 | iteration 17/100
# best = -1.6112664759883377
# trial 2/3 | iteration 18/100
# best = -1.6112664759883377
# trial 2/3 | iteration 19/100
# best = -1.6112664759883377
# trial 2/3 | iteration 20/100
# best = -1.6112664759883377
# trial 2/3 | iteration 21/100
# best = -1.6112664759883377
# trial 2/3 | iteration 22/100
# best = -1.6112664759883377
# trial 2/3 | iteration 23/100
# best = -1.6112664759883377
# trial 2/3 | iteration 24/100
# best = -1.6112664759883377
# trial 2/3 | iteration 25/100
# best = -1.6112664759883377
# trial 2/3 | iteration 26/100
# best = -1.6112664759883377
# trial 2/3 | iteration 27/100
# best = -1.6112664759883377
# trial 2/3 | iteration 28/100
# best = -1.6112664759883377
# trial 2/3 | iteration 29/100
# best = -1.6112664759883377
# trial 2/3 | iteration 30/100
# best = -1.6112664759883377
# trial 2/3 | iteration 31/100
# best = -1.6112664759883377
# trial 2/3 | iteration 32/100
# best = -1.6112664759883377
# trial 2/3 | iteration 33/100
# best = -1.6112664759883377
# trial 2/3 | iteration 34/100
# best = -1.6112664759883377
# trial 2/3 | iteration 35/100
# best = -1.6112664759883377
# trial 2/3 | iteration 36/100
# best = -1.6112664759883377
# trial 2/3 | iteration 37/100
# best = -1.6112664759883377
# trial 2/3 | iteration 38/100
# best = -1.6112664759883377
# trial 2/3 | iteration 39/100
# best = -1.6112664759883377
# trial 2/3 | iteration 40/100
# best = -1.6112664759883377
# trial 2/3 | iteration 41/100
# best = -1.6112664759883377
# trial 2/3 | iteration 42/100
# best = -1.6112664759883377
# trial 2/3 | iteration 43/100
# best = -1.6112664759883377
# trial 2/3 | iteration 44/100
# best = -1.6112664759883377
# trial 2/3 | iteration 45/100
# best = -1.6112664759883377
# trial 2/3 | iteration 46/100
# best = -1.6112664759883377
# trial 2/3 | iteration 47/100
# best = -1.6112664759883377
# trial 2/3 | iteration 48/100
# best = -1.6112664759883377
# trial 2/3 | iteration 49/100
# best = -1.6112664759883377
# trial 2/3 | iteration 50/100
# best = -1.6112664759883377
# trial 2/3 | iteration 51/100
# best = -1.6112664759883377
# trial 2/3 | iteration 52/100
# best = -1.6112664759883377
# trial 2/3 | iteration 53/100
# best = -1.6112664759883377
# trial 2/3 | iteration 54/100
# best = -1.6112664759883377
# trial 2/3 | iteration 55/100
# best = -1.6112664759883377
# trial 2/3 | iteration 56/100
# best = -1.6112664759883377
# trial 2/3 | iteration 57/100
# best = -1.6112664759883377
# trial 2/3 | iteration 58/100
# best = -1.6112664759883377
# trial 2/3 | iteration 59/100
# best = -1.6112664759883377
# trial 2/3 | iteration 60/100
# best = -1.6112664759883377
# trial 2/3 | iteration 61/100
# best = -1.6112664759883377
# trial 2/3 | iteration 62/100
# best = -1.6112664759883377
# trial 2/3 | iteration 63/100
# best = -1.6112664759883377
# trial 2/3 | iteration 64/100
# best = -1.6112664759883377
# trial 2/3 | iteration 65/100
# best = -1.6112664759883377
# trial 2/3 | iteration 66/100
# best = -1.6112664759883377
# trial 2/3 | iteration 67/100
# best = -1.6112664759883377
# trial 2/3 | iteration 68/100
# best = -1.6112664759883377
# trial 2/3 | iteration 69/100
# best = -1.6112664759883377
# trial 2/3 | iteration 70/100
# best = -1.6112664759883377
# trial 2/3 | iteration 71/100
# best = -1.6112664759883377
# trial 2/3 | iteration 72/100
# best = -1.6112664759883377
# trial 2/3 | iteration 73/100
# best = -1.6112664759883377
# trial 2/3 | iteration 74/100
# best = -1.6112664759883377
# trial 2/3 | iteration 75/100
# best = -1.6112664759883377
# trial 2/3 | iteration 76/100
# best = -1.6112664759883377
# trial 2/3 | iteration 77/100
# best = -1.6112664759883377
# trial 2/3 | iteration 78/100
# best = -1.6112664759883377
# trial 2/3 | iteration 79/100
# best = -1.6112664759883377
# trial 2/3 | iteration 80/100
# best = -1.6112664759883377
# trial 2/3 | iteration 81/100
# best = -1.6112664759883377
# trial 2/3 | iteration 82/100
# best = -1.6112664759883377
# trial 2/3 | iteration 83/100
# best = -1.6112664759883377
# trial 2/3 | iteration 84/100
# best = -1.6112664759883377
# trial 2/3 | iteration 85/100
# best = -1.6112664759883377
# trial 2/3 | iteration 86/100
# best = -1.6112664759883377
# trial 2/3 | iteration 87/100
# best = -1.6112664759883377
# trial 2/3 | iteration 88/100
# best = -1.6112664759883377
# trial 2/3 | iteration 89/100
# best = -1.6112664759883377
# trial 2/3 | iteration 90/100
# best = -1.6112664759883377
# trial 2/3 | iteration 91/100
# best = -1.6112664759883377
# trial 2/3 | iteration 92/100
# best = -1.6112664759883377
# trial 2/3 | iteration 93/100
# best = -1.6112664759883377
# trial 2/3 | iteration 94/100
# best = -1.6112664759883377
# trial 2/3 | iteration 95/100
# best = -1.6112664759883377
# trial 2/3 | iteration 96/100
# best = -1.6112664759883377
# trial 2/3 | iteration 97/100
# best = -1.6112664759883377
# trial 2/3 | iteration 98/100
# best = -1.6112664759883377
# trial 2/3 | iteration 99/100
# best = -1.6112664759883377
# trial 2/3 | iteration 100/100
# best = -1.6112664759883377
# trial 3/3 | iteration 1/100
# best = -2.5369190203732797
# trial 3/3 | iteration 2/100
# best = -2.5369190203732797
# trial 3/3 | iteration 3/100
# best = -2.5369190203732797
# trial 3/3 | iteration 4/100
# best = -2.5369190203732797
# trial 3/3 | iteration 5/100
# best = -2.5369190203732797
# trial 3/3 | iteration 6/100
# best = -2.5369190203732797
# trial 3/3 | iteration 7/100
# best = -2.5369190203732797
# trial 3/3 | iteration 8/100
# best = -2.5369190203732797
# trial 3/3 | iteration 9/100
# best = -2.5369190203732797
# trial 3/3 | iteration 10/100
# best = -1.8577466701816836
# trial 3/3 | iteration 11/100
# best = -1.8577466701816836
# trial 3/3 | iteration 12/100
# best = -1.8577466701816836
# trial 3/3 | iteration 13/100
# best = -1.8577466701816836
# trial 3/3 | iteration 14/100
# best = -1.8577466701816836
# trial 3/3 | iteration 15/100
# best = -1.8577466701816836
# trial 3/3 | iteration 16/100
# best = -1.8577466701816836
# trial 3/3 | iteration 17/100
# best = -1.8577466701816836
# trial 3/3 | iteration 18/100
# best = -1.8577466701816836
# trial 3/3 | iteration 19/100
# best = -1.8577466701816836
# trial 3/3 | iteration 20/100
# best = -1.8577466701816836
# trial 3/3 | iteration 21/100
# best = -1.8577466701816836
# trial 3/3 | iteration 22/100
# best = -1.8577466701816836
# trial 3/3 | iteration 23/100
# best = -1.8577466701816836
# trial 3/3 | iteration 24/100
# best = -1.8577466701816836
# trial 3/3 | iteration 25/100
# best = -1.8577466701816836
# trial 3/3 | iteration 26/100
# best = -1.8577466701816836
# trial 3/3 | iteration 27/100
# best = -1.8577466701816836
# trial 3/3 | iteration 28/100
# best = -1.8577466701816836
# trial 3/3 | iteration 29/100
# best = -1.8577466701816836
# trial 3/3 | iteration 30/100
# best = -1.8577466701816836
# trial 3/3 | iteration 31/100
# best = -1.8577466701816836
# trial 3/3 | iteration 32/100
# best = -1.8577466701816836
# trial 3/3 | iteration 33/100
# best = -1.8577466701816836
# trial 3/3 | iteration 34/100
# best = -1.8577466701816836
# trial 3/3 | iteration 35/100
# best = -1.8577466701816836
# trial 3/3 | iteration 36/100
# best = -1.8577466701816836
# trial 3/3 | iteration 37/100
# best = -1.8577466701816836
# trial 3/3 | iteration 38/100
# best = -1.8577466701816836
# trial 3/3 | iteration 39/100
# best = -1.8577466701816836
# trial 3/3 | iteration 40/100
# best = -1.8577466701816836
# trial 3/3 | iteration 41/100
# best = -1.8577466701816836
# trial 3/3 | iteration 42/100
# best = -1.8577466701816836
# trial 3/3 | iteration 43/100
# best = -1.8577466701816836
# trial 3/3 | iteration 44/100
# best = -1.8577466701816836
# trial 3/3 | iteration 45/100
# best = -1.8577466701816836
# trial 3/3 | iteration 46/100
# best = -1.8577466701816836
# trial 3/3 | iteration 47/100
# best = -1.8577466701816836
# trial 3/3 | iteration 48/100
# best = -1.8577466701816836
# trial 3/3 | iteration 49/100
# best = -1.8577466701816836
# trial 3/3 | iteration 50/100
# best = -1.8577466701816836
# trial 3/3 | iteration 51/100
# best = -1.8577466701816836
# trial 3/3 | iteration 52/100
# best = -1.8577466701816836
# trial 3/3 | iteration 53/100
# best = -1.8577466701816836
# trial 3/3 | iteration 54/100
# best = -1.8577466701816836
# trial 3/3 | iteration 55/100
# best = -1.8577466701816836
# trial 3/3 | iteration 56/100
# best = -1.8577466701816836
# trial 3/3 | iteration 57/100
# best = -1.8577466701816836
# trial 3/3 | iteration 58/100
# best = -1.8577466701816836
# trial 3/3 | iteration 59/100
# best = -1.8577466701816836
# trial 3/3 | iteration 60/100
# best = -1.8577466701816836
# trial 3/3 | iteration 61/100
# best = -1.8577466701816836
# trial 3/3 | iteration 62/100
# best = -1.8577466701816836
# trial 3/3 | iteration 63/100
# best = -1.8577466701816836
# trial 3/3 | iteration 64/100
# best = -1.8577466701816836
# trial 3/3 | iteration 65/100
# best = -1.8577466701816836
# trial 3/3 | iteration 66/100
# best = -1.8577466701816836
# trial 3/3 | iteration 67/100
# best = -1.8577466701816836
# trial 3/3 | iteration 68/100
# best = -1.8577466701816836
# trial 3/3 | iteration 69/100
# best = -1.8577466701816836
# trial 3/3 | iteration 70/100
# best = -1.8577466701816836
# trial 3/3 | iteration 71/100
# best = -1.8577466701816836
# trial 3/3 | iteration 72/100
# best = -1.8577466701816836
# trial 3/3 | iteration 73/100
# best = -1.8577466701816836
# trial 3/3 | iteration 74/100
# best = -1.8577466701816836
# trial 3/3 | iteration 75/100
# best = -1.8577466701816836
# trial 3/3 | iteration 76/100
# best = -1.8577466701816836
# trial 3/3 | iteration 77/100
# best = -1.8577466701816836
# trial 3/3 | iteration 78/100
# best = -1.8577466701816836
# trial 3/3 | iteration 79/100
# best = -1.8577466701816836
# trial 3/3 | iteration 80/100
# best = -1.8577466701816836
# trial 3/3 | iteration 81/100
# best = -1.8577466701816836
# trial 3/3 | iteration 82/100
# best = -1.8577466701816836
# trial 3/3 | iteration 83/100
# best = -1.8577466701816836
# trial 3/3 | iteration 84/100
# best = -1.8577466701816836
# trial 3/3 | iteration 85/100
# best = -1.8577466701816836
# trial 3/3 | iteration 86/100
# best = -1.8577466701816836
# trial 3/3 | iteration 87/100
# best = -1.8577466701816836
# trial 3/3 | iteration 88/100
# best = -1.8577466701816836
# trial 3/3 | iteration 89/100
# best = -1.8577466701816836
# trial 3/3 | iteration 90/100
# best = -1.8577466701816836
# trial 3/3 | iteration 91/100
# best = -1.8577466701816836
# trial 3/3 | iteration 92/100
# best = -1.8577466701816836
# trial 3/3 | iteration 93/100
# best = -1.8577466701816836
# trial 3/3 | iteration 94/100
# best = -1.8577466701816836
# trial 3/3 | iteration 95/100
# best = -1.8577466701816836
# trial 3/3 | iteration 96/100
# best = -1.8577466701816836
# trial 3/3 | iteration 97/100
# best = -1.8577466701816836
# trial 3/3 | iteration 98/100
# best = -1.8577466701816836
# trial 3/3 | iteration 99/100
# best = -1.8577466701816836
# trial 3/3 | iteration 100/100
# best = -1.8577466701816836

# %%
# plot results

def ci(y):
    return 1.96 * y.std(axis=0) / np.sqrt(N_TRIALS)


GLOBAL_MAXIMUM = 0.0


obs = np.arange(N_ITERS + 1) * N_CANDIDATES
y1 = np.asarray(best_values.to('cpu'))
y2 = np.asarray(best_values_2.to('cpu'))

fig, ax = plt.subplots(1, 1, figsize=(8, 6))
ax.errorbar(obs, y1.mean(axis=0), yerr=ci(y1), label="nu = 1.5", linewidth=1.5)
ax.errorbar(obs, y2.mean(axis=0), yerr=ci(y2), label="nu = 0.5", linewidth=1.5)
plt.plot([0, N_ITERS * N_CANDIDATES], [GLOBAL_MAXIMUM] * 2, 'k', label="true best objective", linewidth=2)
ax.set_ylim(bottom=-5, top=1)
ax.set(xlabel='number of observations (beyond initial points)', ylabel='best objective value')
ax.legend(loc="lower right")
